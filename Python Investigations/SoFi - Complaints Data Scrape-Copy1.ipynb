# %% [markdown]
# ## SoFi Gives Personal Loans Alternatives As Interest Rates Climb, But Is It Safe?
#
# Story: SoFi Technologies, Inc. is an American online personal finance company and online bank. Based in San Francisco, SoFi provides financial products including student loan refinancing, mortgages, personal loans, credit card, investing, and banking through both mobile app and desktop interfaces.
#
# This is a personal finance story that outlines the pros and cons of using SoFi, with real anecdotes from users.
#
# <a href="https://www.consumerfinance.gov/data-research/consumer-complaints/search/?company=Social%20Finance%2C%20Inc.&date_received_max=2023-11-26&date_received_min=2011-12-01&has_narrative=true&page=1&searchField=all&size=25&sort=created_date_desc&tab=List">Website link</a>
#
#
# <a href="https://cfpb.github.io/api/ccdb/api.html">API link</a>

# %% [raw]
# We will scrape data from the Consumer Finance Protection Bureau, a database with complaints from real users. Steps: We're trying to scrape this page.
# 1. Build API call
# 2. Create dataset
# 3. Figure out next step

# %%
## import libraries
import requests
import pandas as pd
from icecream import ic
import itertools

# %%
# endpoint
endpoint = "https://www.consumerfinance.gov/data-research/consumer-complaints/search/api/v1/?field=all&size=100&sort=relevance_desc&format=json&no_aggs=false&no_highlight=false&company=Social%20Finance%2C%20Inc.%20"

# %%
# endpoint = "https://www.consumerfinance.gov/data-research/consumer-complaints/search/api/v1/5773613"

# %%
## get data
response = requests.get(endpoint)
data = response.json()
data
# print(response)
# Out:
# [{'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '4062074',
#   '_score': None,
#   '_source': {'product': 'Payday loan, title loan, or personal loan',
#    'complaint_what_happened': '',
#    'date_sent_to_company': '2021-01-12T12:00:00-05:00',
#    'issue': 'Problem with additional add-on products or services',
#    'sub_product': 'Personal line of credit',
#    'zip_code': '97838',
#    'tags': 'Servicemember',
#    'complaint_id': '4062074',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent not provided',
#    'company_response': 'Closed with monetary relief',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2021-01-12T12:00:00-05:00',
#    'state': 'OR',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': None},
#   'sort': [3948]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '3162894',
#   '_score': None,
#   '_source': {'product': 'Checking or savings account',
#    'complaint_what_happened': "I was promised a {$200.00} bonus for opening my 'SoFi Money ' account. I joined a waiting list and later was sent an email telling me my account was opened successfully. SoFi falsely advertised this promotion and conducted a bait-and-switch scheme, baited new customer and deny the promotion without notice.",
#    'date_sent_to_company': '2019-02-26T12:00:00-05:00',
#    'issue': 'Managing an account',
#    'sub_product': 'Other banking product or service',
#    'zip_code': '94536',
#    'tags': None,
#    'complaint_id': '3162894',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2019-02-26T12:00:00-05:00',
#    'state': 'CA',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Banking errors'},
#   'sort': [4730]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '4267041',
#   '_score': None,
#   '_source': {'product': 'Payday loan, title loan, or personal loan',
#    'complaint_what_happened': 'On Monday, XX/XX/2021, I was looking for a {$70000.00} Personal Loan to fund a renovation I am running in my house and I checked the rates with SoFi ( Social Finance , Inc. ) and they were attractive. They only pulled a soft credit with a credit bureau ; they pre approved me. \n\nThen, next step was to send an official application, when they would pulled my credit info from a bureau. In a given screen about immigration status they offered 3 options to be chosen from : XXXX, XXXX XXXX holder, Non-immigrant ( option that would limit the the loan to T {$35000.00} XXXX. I, then, on the same day XX/XX/XXXX, chatted with a customer support representative BEFORE SUBMITTING THE APPLICATION to understand what I should do as my situation is having an EAD/Advance Parole holder with a EB-5 Green Card application approved ( I-140 ) awaiting the card to be issued. I was informed by the agent that if I had the approval letter I could submit my application, as a green card holder. \nNote : I was logged in so they have that conversation store in their system. \n\nI proceed with the application and was approved for up to {$90000.00}. I ended up keeping a {$70000.00} request. Following, they requested me to send me my docs and after a lot of back and forth a agent calledXX/XX/XXXX. stated clearly that I had to submit an I-797 Form with my green card approval to be finally approved. I sent that and after more back and forth the agent XXXX XXXX denied the loan unless I fulfilled this absurd request to add a XXXX or XXXX XX/XX/XXXX holder to my application as a co-signer ( even to get less than {$35000.00}, the opposite of what they stated before ). \n\nI refused to do so as I earned a great credit as an individual, paying my bills and taxes diligently and I am the only responsible for my personal finances. Then, they denied my request, left me without the loan and with a credit score hurt by their hard inquiry - even though I presented all documents requested.',
#    'date_sent_to_company': '2021-04-02T12:00:00-05:00',
#    'issue': 'Getting the loan',
#    'sub_product': 'Installment loan',
#    'zip_code': '33328',
#    'tags': None,
#    'complaint_id': '4267041',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2021-04-02T12:00:00-05:00',
#    'state': 'FL',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': None},
#   'sort': [4907]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '4181406',
#   '_score': None,
#   '_source': {'product': 'Debt collection',
#    'complaint_what_happened': '',
#    'date_sent_to_company': '2021-03-03T12:00:00-05:00',
#    'issue': 'Attempts to collect debt not owed',
#    'sub_product': 'I do not know',
#    'zip_code': '10469',
#    'tags': None,
#    'complaint_id': '4181406',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent not provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2021-03-03T12:00:00-05:00',
#    'state': 'NY',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Debt was result of identity theft'},
#   'sort': [5333]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '2886114',
#   '_score': None,
#   '_source': {'product': 'Student loan',
#    'complaint_what_happened': 'On XX/XX/XXXX of XXXX, I consolidated 6 private loans under three different loan servicers : XXXX ( 1 loanXXXX XXXX XXXX {$7200.00} ), XXXX ( 3 loans- XXXX XXXX XXXX- {$1300.00}, XXXX- {$2700.00}, and Perkins loan- {$3000.00} ) , and XXXX ( 2 loans-XXXX XXXX- {$6500.00} and XXXX- {$8600.00} ) with Sofi for XXXX. XXXX then became my consolidated loan servicer. In XXXX of XXXX, I noticed that I kept receiving XXXX bank statements to re-pay my loan. I also noticed that my beginning balance at XXXX ( {$30000.00} ) dropped to {$20000.00} within 3 months. I called Sofi 4 times in regards to this situation. The final representantive I spoke with ( a member of their specialist team ), stated that Sofi made an error and did not include my XXXX loan. A previous representative I spoke with told me that Sofi would " take care of the issue since this was an error on Sofi \'s end. \'\' I was never notified by Sofi about the exclusion of the XXXX loan and thus, was late on my XXXX payments as I was under the impression that Sofi had consolidated all 6 loans. Sofi is now stating that I must re-start the loan application process and now consolidate XXXX with XXXX in order to resolve the situation for their error.',
#    'date_sent_to_company': '2018-04-24T12:00:00-05:00',
#    'issue': 'Dealing with your lender or servicer',
#    'sub_product': 'Private student loan',
#    'zip_code': '43202',
#    'tags': None,
#    'complaint_id': '2886114',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2018-04-24T12:00:00-05:00',
#    'state': 'OH',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Received bad information about your loan'},
#   'sort': [6378]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '3393407',
#   '_score': None,
#   '_source': {'product': 'Checking or savings account',
#    'complaint_what_happened': 'I previously opened an installment loan with Sofi ; that was paid off. Sofi then proceeded to add an investment and checking account to my profile.I did not ask for these accounts. As a result, my tax filings are much more complicated. My accountant is charging me a higher amount of money to complete filings. \n\nI need Sofi to close these accounts and reimburse me for the extra costs I have incurred for accounts I did NOT authorize to be opened. \n\nCLOSE my accounts. I am DONE with my business with you and I was DONE when I paid off my loan!',
#    'date_sent_to_company': '2019-10-02T12:00:00-05:00',
#    'issue': 'Closing an account',
#    'sub_product': 'Checking account',
#    'zip_code': '75230',
#    'tags': None,
#    'complaint_id': '3393407',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2019-10-02T12:00:00-05:00',
#    'state': 'TX',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': "Can't close your account"},
#   'sort': [6452]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '4805198',
#   '_score': None,
#   '_source': {'product': 'Credit reporting, credit repair services, or other personal consumer reports',
#    'complaint_what_happened': 'SoFi lending is reporting an account on my credit report that I do not owe. In 2017, SoFi sued me claiming I owed this debt, but I do not and the case was dismissed. Despite this, SoFi continues to unlawfully pursue collection of this debt.\n\nI have repeatedly disputed this account with all three credit bureaus and I have written to SoFi directly to dispute the debt. However, SoFi continues to verify the debt with the credit bureaus and provide inaccurate account information.\n\nI am requesting that SoFi immediately remove this account from my credit report with all three bureaus, including, but not limited to XXXX, XXXX, and XXXX. I am further requesting that SoFi discontinue all unlawful collection activity.',
#    'date_sent_to_company': '2021-10-13T12:00:00-05:00',
#    'issue': 'Incorrect information on your report',
#    'sub_product': 'Credit reporting',
#    'zip_code': '770XX',
#    'tags': None,
#    'complaint_id': '4805198',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2021-10-13T12:00:00-05:00',
#    'state': 'TX',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Account information incorrect'},
#   'sort': [7760]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '4168280',
#   '_score': None,
#   '_source': {'product': 'Credit reporting, credit repair services, or other personal consumer reports',
#    'complaint_what_happened': '',
#    'date_sent_to_company': '2021-02-26T12:00:00-05:00',
#    'issue': "Problem with a credit reporting company's investigation into an existing problem",
#    'sub_product': 'Credit reporting',
#    'zip_code': '47905',
#    'tags': None,
#    'complaint_id': '4168280',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent not provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2021-02-26T12:00:00-05:00',
#    'state': 'IN',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Problem with personal statement of dispute'},
#   'sort': [9082]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '4359168',
#   '_score': None,
#   '_source': {'product': 'Student loan',
#    'complaint_what_happened': 'on XX/XX/2021. I applied for student debt consolidation from XXXX to Sofi. I was under the impression that I had XXXX days ( XX/XX/2021 ) to agree to the loan. Upon hearing that there may be talks to cancel student debt and refinance with XXXX instead, i asked Sofi to cancel my refinance. They told me " no \'\' that the deadline was XX/XX/2021. The loan documents that I received from Sofi repeatedly stated XX/XX/XXXX. When I contacted Sofi they told me i can ask XXXX to return the check and cancel the refinance. When I contacted XXXX, they told me they cant do anything. I feel like I was misled, any loan that I have applied for gives XXXX days for final approval. No one from Sofi reached out to me regarding the XXXX day deadline, while all the paperwork stated XX/XX/2021. I do not know how many other students are being misled. I would like my loan returned to XXXX XXXX XXXX XXXX XXXX XXXX  and cancel any consolidation with SoFi. Anyone reading this, keep your student loans with the XXXX XXXX XXXX and do not get misled by the private loan companies.',
#    'date_sent_to_company': '2021-05-07T12:00:00-05:00',
#    'issue': 'Dealing with your lender or servicer',
#    'sub_product': 'Private student loan',
#    'zip_code': '49503',
#    'tags': None,
#    'complaint_id': '4359168',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2021-05-07T12:00:00-05:00',
#    'state': 'MI',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Received bad information about your loan'},
#   'sort': [9260]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '3163904',
#   '_score': None,
#   '_source': {'product': 'Student loan',
#    'complaint_what_happened': "I applied as a cosigner in XX/XX/2019 with SOFI to refinance my daughters student loans. I completed the credit application and provided all documentation requested. I was never notified of a credit decision. My daughter was sent an email on XX/XX/XXXX that I was ineligible as a cosigner. I contacted SOFI on XX/XX/XXXX, and was told over the phone that my credit application was WITHDRAWN and an email was sent to me on XX/XX/XXXX, I did not know what WITHDRAWN meant considering i applied for credit and provided all necessary documentation for a credit review and was told that a hard credit pull was completed. I asked to speak to a manager to file a formal complaint based on the fact that I applied for credit regardless I was a cosigner or primary that I completed a credit application and provided any requested supporting documents which included a hard credit pull that I was not formally notified of a decision simply that they could just withdraw my request for credit. My complaint I believe includes several of illegal business practices. I believe if I did not qualify under SOFI 's standards then the application should have been declined, I should have received a formal notification in writing which would allow me to follow up as a consumer. I do not understand how a company can legally pull my credit and then simply Withdraw my application and not provide information to the consumer. I do not understand how the other party involved my daughter the primary applicant received an email that I as the cosigner was ineligible, when I myself as the applicant did not receive proper notice. I believe legally when a consumer applies for credit via a credit application provides all necessary documentation to complete the application the application needs to either be declined or approved and the consumer needs to be formally notified. I do not see how SOFI can legally pull a hard credit pull find a reason not to qualify my request and simply WITHDRAW my application. Tell me that my application is Withdrawn, and email my daughter that I am ineligible and not give me any information on why I failed to meet or what their credit requirements entail.",
#    'date_sent_to_company': '2019-02-26T12:00:00-05:00',
#    'issue': 'Getting a loan',
#    'sub_product': 'Private student loan',
#    'zip_code': '60103',
#    'tags': None,
#    'complaint_id': '3163904',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2019-02-26T12:00:00-05:00',
#    'state': 'IL',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Fraudulent loan'},
#   'sort': [10812]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '5742656',
#   '_score': None,
#   '_source': {'product': 'Checking or savings account',
#    'complaint_what_happened': 'On XX/XX/XXXX, I referred a friend for a SoFi banking account based on a promotion where we both would receive {$15.00} and I would receive {$25.00}. \n\nMy friend completed all requires steps of creating a login, opening, and funding the account. However, a referral bonus did not post.\n\nAfter discussing with an agent, I was told that Sofi decided to end the promotion early and that they were not currently paying out bonuses. I informed the rep that I met the terms before the promotion ended and they were unsure if the promotion would be paid. I was told a complaint would be filed on my behalf but never heard back. Today on XX/XX/XXXX, I reached out to Sofi again and they told me there were no longer any referral records or tickets logged on my account. They appear to have never investigated this issue.',
#    'date_sent_to_company': '2022-07-06T12:00:00-05:00',
#    'issue': 'Opening an account',
#    'sub_product': 'Checking account',
#    'zip_code': '22206',
#    'tags': None,
#    'complaint_id': '5742656',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2022-07-06T12:00:00-05:00',
#    'state': 'VA',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': "Didn't receive terms that were advertised"},
#   'sort': [13034]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '4400382',
#   '_score': None,
#   '_source': {'product': 'Credit reporting, credit repair services, or other personal consumer reports',
#    'complaint_what_happened': '',
#    'date_sent_to_company': '2021-05-24T12:00:00-05:00',
#    'issue': "Problem with a credit reporting company's investigation into an existing problem",
#    'sub_product': 'Credit reporting',
#    'zip_code': '02145',
#    'tags': None,
#    'complaint_id': '4400382',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent not provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2021-05-24T12:00:00-05:00',
#    'state': 'MA',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Their investigation did not fix an error on your report'},
#   'sort': [13466]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '4564242',
#   '_score': None,
#   '_source': {'product': 'Checking or savings account',
#    'complaint_what_happened': "In XX/XX/2021, I filed disputes for transactions in my account that I didn't authorize that happened on my debit card as well as a check that was written on my account and for filing the dispute the closed my account never refunded my transactions and now I can't even access my bank statements I had with them. I had the XXXX XXXX XXXX that was supposed to be deposited into this account and they rejected it as well.",
#    'date_sent_to_company': '2021-07-21T12:00:00-05:00',
#    'issue': 'Managing an account',
#    'sub_product': 'Checking account',
#    'zip_code': '609XX',
#    'tags': None,
#    'complaint_id': '4564242',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2021-07-21T12:00:00-05:00',
#    'state': 'IL',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Deposits and withdrawals'},
#   'sort': [13654]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '4331760',
#   '_score': None,
#   '_source': {'product': 'Credit card or prepaid card',
#    'complaint_what_happened': '',
#    'date_sent_to_company': '2021-04-27T12:00:00-05:00',
#    'issue': 'Problem with a purchase shown on your statement',
#    'sub_product': 'General-purpose credit card or charge card',
#    'zip_code': '25404',
#    'tags': None,
#    'complaint_id': '4331760',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'N/A',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Phone',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2021-04-27T12:00:00-05:00',
#    'state': 'WV',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': "Credit card company isn't resolving a dispute about a purchase on your statement"},
#   'sort': [19172]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '5660756',
#   '_score': None,
#   '_source': {'product': 'Debt collection',
#    'complaint_what_happened': 'I have contact this company about this debt that was inserted into my credit profile I have contact the company asking this company to contact my attorney about this debt this account refuse and is still threatening me and now is currently in litigation. This company threaten for my credit to be rued and this company is single handily worked on destroying my credit and I am asking for help before I processed with legal actions. Thanks',
#    'date_sent_to_company': '2022-06-12T12:00:00-05:00',
#    'issue': 'Took or threatened to take negative or legal action',
#    'sub_product': 'Payday loan debt',
#    'zip_code': '18951',
#    'tags': 'Servicemember',
#    'complaint_id': '5660756',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2022-06-12T12:00:00-05:00',
#    'state': 'PA',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Threatened or suggested your credit would be damaged'},
#   'sort': [19305]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '5664714',
#   '_score': None,
#   '_source': {'product': 'Checking or savings account',
#    'complaint_what_happened': "Hello there, I'm writing in because I have, seemingly, no other alternative. The company in question is SOFI Financial. I had a checking and savings account with them that has been opened for years. Recently, I also applied for, and was approved for a credit card with them. I activated said card and was declined. I thought that was odd, so I tried once more, and was declined. I received no call from them at all regarding this- which I also found odd. \n\nI call and they tell me that my entire account, checking/savings/credit card, has been frozen for suspected fraud. Mind you, my checking account has no transactions whatsoever on them. My credit card was brand new. I had planned to utilize both once I received the card. \n\nMy actually issue lies in the fact that reaching someone at SOFI who can give me actual information as to why my account was frozen, or any details at all about my account is near impossible. Reaching a general agent is fine, until you get through and they direct you to reach their fraud team who I can never get through to whatsoever. Immediately when I am transferred, or call the number directly, I am sent to a voicemail box in which I have left 4 voicemails on already on the following dates : XX/XX/XXXX, XX/XX/XXXX, XX/XX/XXXX, XX/XX/XXXX. \n\nI have received no response or correspondence back. I have also asked for their general support team to have a supervisor call me back and have received nothing back in return either. \n\nAll accounts are frozen without any reason, ways to resolve the freeze, or ways in which to reach someone who can provide me any information at all.",
#    'date_sent_to_company': '2022-06-13T12:00:00-05:00',
#    'issue': 'Managing an account',
#    'sub_product': 'Checking account',
#    'zip_code': '33401',
#    'tags': None,
#    'complaint_id': '5664714',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2022-06-13T12:00:00-05:00',
#    'state': 'FL',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Deposits and withdrawals'},
#   'sort': [21045]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '2560444',
#   '_score': None,
#   '_source': {'product': 'Student loan',
#    'complaint_what_happened': 'Every month I receive from XXXX an invitation to lower the cost of my student debt : " We \'ve missed you! \'\' Simply log in and check your rates. I apply and always get rejected. they keep sending me an invitation to re-apply " XXXXXXXX is the 5th one of these I \'ve received. The latest one onXX/XX/XXXX, 2017.',
#    'date_sent_to_company': '2017-06-27T12:00:00-05:00',
#    'issue': 'Getting a loan',
#    'sub_product': 'Private student loan',
#    'zip_code': '085XX',
#    'tags': 'Older American',
#    'complaint_id': '2560444',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2017-06-27T12:00:00-05:00',
#    'state': 'NJ',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Confusing or misleading advertising'},
#   'sort': [22509]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '3045319',
#   '_score': None,
#   '_source': {'product': 'Payday loan, title loan, or personal loan',
#    'complaint_what_happened': "In early XX/XX/2018, I applied on www.SoFi.com for a personal loan. I have excellent credit and income and met all of the qualifications necessary to receive the loan amount of $ XXXX that I applied for. I went through the SoFi account review process submitting all required bank account documentation and proof of income and was approved for a loan. When the review process was completed I was sent my loan agreement and signed it on XX/XX/2018. My first payment on the loan was to be due on XX/XX/2018. However, for some reason, SoFi has refused to fund my loan and hasn't given me any plausible explanation. It is now XX/XX/2018 and SoFi has not funded the loan per our agreement. Every time I have contacted the company about the status of my loan they have only offered vague excuses and empty promises of the funding being ready to go. My SoFi account has now been placed in permanent 'signature review ' status. SoFi recently notified me that my application has expired even after I have provided everything that they've asked for. Based on my experience with this company I strongly suspect that I have been discriminated against based on race or because I am a senior citizen.",
#    'date_sent_to_company': '2018-10-14T12:00:00-05:00',
#    'issue': 'Getting the loan',
#    'sub_product': 'Installment loan',
#    'zip_code': '20874',
#    'tags': None,
#    'complaint_id': '3045319',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2018-10-14T12:00:00-05:00',
#    'state': 'MD',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': None},
#   'sort': [22880]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '3163432',
#   '_score': None,
#   '_source': {'product': 'Payday loan, title loan, or personal loan',
#    'complaint_what_happened': 'SoFi heavily solicited me with a " pre-approved \'\' offer of a loan for {$50000.00}. I finally accepted their pre-approval and submitted the requested documentation to prove identity and income. Shortly after discovering I was XXXX XXXX through means of my driver \'s license the company denied my loan citing an inability to verify my income. I have worked for the same company for well over a year, the company did not ask me to provide additional documents or even give me a chance to " verify \'\' my income. When I called to have a more detailed description of the reason for denial the representative thought the denial reason was " odd \'\' and said so directly. I personally know of other well qualified high earning XXXX XXXX that received pre-approvals and were then " denied \'\' mysteriously from this company after their identity was verified. It is my strong belief that this company discriminates against XXXX XXXX. When I asked for how they determined my income could not be " verified \'\' they refused to release the name of any agency or consumer reporting agency that they based their decision off of. They wrongly justified their position of not releasing the agency used to make their decision as proprietary information, despite the fair credit reporting act specifying otherwise. There unethical lending practices lured me into applying for a loan product with them, leading to a hard inquiry on my credit which has prevented me from securing the loan I need with a more reputable lender.',
#    'date_sent_to_company': '2019-02-26T12:00:00-05:00',
#    'issue': 'Getting the loan',
#    'sub_product': 'Installment loan',
#    'zip_code': '53092',
#    'tags': None,
#    'complaint_id': '3163432',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2019-02-26T12:00:00-05:00',
#    'state': 'WI',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': None},
#   'sort': [23892]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '3005471',
#   '_score': None,
#   '_source': {'product': 'Student loan',
#    'complaint_what_happened': 'SoFi failed to let me know why they denied my loan refinance request.',
#    'date_sent_to_company': '2018-08-29T12:00:00-05:00',
#    'issue': 'Dealing with your lender or servicer',
#    'sub_product': 'Private student loan',
#    'zip_code': '224XX',
#    'tags': None,
#    'complaint_id': '3005471',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2018-08-29T12:00:00-05:00',
#    'state': 'VA',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Received bad information about your loan'},
#   'sort': [26336]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '3928673',
#   '_score': None,
#   '_source': {'product': 'Checking or savings account',
#    'complaint_what_happened': 'On XX/XX/2020, I opened a " Money \'\' account with SoFi. The " Cash Back Terms \'\' for this account said, " For each eligible transaction made within 60 days of the date your new SoFi Money Account is opened, SoFi will credit your account for an amount equal to 5 % of each eligible purchase, up to a maximum of {$100.00} during the Promotion Period. \'\' By XX/XX/2020 ( well within the 60-day limit ), I had made more than {$2000.00} of eligible purchases, meaning that I should receive {$100.00} cash back. SoFi has never credited my account with any cash back ( see account history ). \n\nOn XX/XX/2020, XX/XX/2020, and XX/XX/2020, I chatted with SoFi to try to resolve this issue ( see various transcripts ). On XX/XX/2020, I was told that I met all the requirements for the {$100.00} cash back, and each time I was told that SoFi was working on the problem and that it would be resolved in 10 business days ( after XX/XX/2020 ) or 3-5 business days ( after XX/XX/2020 ). But even after all of these communications, SoFi has still not credited my account with the {$100.00} cash back. \n\nI am uploading the terms of the account ( XXXX Sign Up Earn 5 % Cash Back SoFi XXXX ) ; chat transcripts from XX/XX/2020, XX/XX/2020, and XX/XX/2020 ; an email showing that a ticket was created on XX/XX/2020 ; and an account history showing all transactions on the account to date ( XXXX Account History SoFi - XXXX ).',
#    'date_sent_to_company': '2020-10-30T12:00:00-05:00',
#    'issue': 'Opening an account',
#    'sub_product': 'Checking account',
#    'zip_code': '76010',
#    'tags': None,
#    'complaint_id': '3928673',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2020-10-30T12:00:00-05:00',
#    'state': 'TX',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': "Didn't receive terms that were advertised"},
#   'sort': [26923]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '4164303',
#   '_score': None,
#   '_source': {'product': 'Credit reporting, credit repair services, or other personal consumer reports',
#    'complaint_what_happened': 'I have tried contacting company in regards to an unauthorized inquiry dated XX/XX/21, however I can not get ahold of anyone in credit dept. I did not apply for an account with SoFi.',
#    'date_sent_to_company': '2021-02-25T12:00:00-05:00',
#    'issue': 'Improper use of your report',
#    'sub_product': 'Credit reporting',
#    'zip_code': '130XX',
#    'tags': None,
#    'complaint_id': '4164303',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2021-02-25T12:00:00-05:00',
#    'state': 'NY',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Reporting company used your report improperly'},
#   'sort': [28904]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '2966797',
#   '_score': None,
#   '_source': {'product': 'Student loan',
#    'complaint_what_happened': "When my student loan payment was set up, I had a different employer, and my monthly payment was set, based on how much money I made with that employer. Now, I no longer work at that company, and I make significantly less money, because I'm working for myself, starting a new business. My loan payment is so high, it is more than I pay for my mortgage, and I'm struggling to make my monthly payments. I physically don't have the money to pay such a high amount every month. I've contacted my student loan company, Sofi, several times ( most recently on XX/XX/18 ) to explain that I need to lower my monthly payment to an amount that reflects my new income, but they tell me there's nothing I can do. My account is now delinquent as a result. To make matters worse, they raise my interest rate every month, making this physically impossible to ever day off in my lifetime. I've already paid back the amount I borrowed and then some, ( over the last 13 years ) but still owe the same amount I started with. I'm just looking to simply lower my monthly payment to a reasonable amount that I can keep up with. Please help.",
#    'date_sent_to_company': '2018-07-18T12:00:00-05:00',
#    'issue': 'Struggling to repay your loan',
#    'sub_product': 'Private student loan',
#    'zip_code': '923XX',
#    'tags': None,
#    'complaint_id': '2966797',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2018-07-18T12:00:00-05:00',
#    'state': 'CA',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Problem lowering your monthly payments'},
#   'sort': [29000]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '5657409',
#   '_score': None,
#   '_source': {'product': 'Checking or savings account',
#    'complaint_what_happened': 'I have a money management checking account at SoFi bank that currently has a balance of {$1100.00}. Since XX/XX/XXXX, I have been unable to access the funds in this account as a temporary restriction has been placed on my account. \n\nIn reaching out to SoFi on XX/XX/XXXX, I was told that I would need to speak with the XXXX XXXX XXXX. Calling the phone number given to reach the XXXX XXXX XXXX provides me with a message stating : that there is no one available to take my call. But to please leave a message with my name, phone number and reference number so that a member of the team may follow up with me. Naturally, I followed these directions ; however, no follow up call or communication of any kind followed the voice message left on XX/XX/XXXX. \n\nOn XX/XX/XXXX, I left a voicemail with the XXXX XXXX XXXX stating the I would like to close my account as I did not have access to the funds within my account nor was I being provided assistance in gaining access to these funds. This voice message went unansweredas did did numerous messages over the next few months left with SoFi requesting that my account be closed and my funds returned to me. The most recent message was left XX/XX/XXXX. This message has not been answered. \n\nIt is extremely frustrating to have my messages ignored by SoFi..especially since I have followed their directions in terms of proper communication with them. It is also frustrating and puzzling that I can not access the funds in my account and that SoFi is actively preventing me from closing my account. Any help that can be provided in closing my SoFi account and having my funds immediately returned to me would be greatly appreciated.',
#    'date_sent_to_company': '2022-06-10T12:00:00-05:00',
#    'issue': 'Closing an account',
#    'sub_product': 'Checking account',
#    'zip_code': '20011',
#    'tags': None,
#    'complaint_id': '5657409',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2022-06-10T12:00:00-05:00',
#    'state': 'DC',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': "Can't close your account"},
#   'sort': [30274]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '5526561',
#   '_score': None,
#   '_source': {'product': 'Checking or savings account',
#    'complaint_what_happened': 'I have not received my debit card although it has been more than the 7-10 business days allotted since the opening of my bank account with SoFi. I also received a message that my bank accounts ( BOTH CHECKING AND SAVINGS ) was frozen on XX/XX/XXXX and have been calling several phone numbers linked to SoFi. Anytime I am able to speak to an actual human, which is rare, they work for other parts of the company and state they have no ability to inform me as to why my account is frozen. They can only see that it is frozen. They always end up directing me to their Fraud Monitoring Team who has a voicemail machine acting as their liaison. Whenever I am transferred, or call their fraud team directly, their is an automated message saying that it is going to get a representative on the line for me immediately followed by, Im sorry all of our agents are busy right now, please leave a message. I have left multiple voicemails, everyday since as well as emails.',
#    'date_sent_to_company': '2022-05-02T12:00:00-05:00',
#    'issue': 'Managing an account',
#    'sub_product': 'Savings account',
#    'zip_code': '80123',
#    'tags': None,
#    'complaint_id': '5526561',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2022-05-02T12:00:00-05:00',
#    'state': 'CO',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Deposits and withdrawals'},
#   'sort': [32023]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '3833248',
#   '_score': None,
#   '_source': {'product': 'Checking or savings account',
#    'complaint_what_happened': "I originally tried to open a Sofi Money account in XXXX using my sister 's referral. The application would not process because I had started an application over a year ago with a different email and that email had to be used. I spent several weeks figuring this out with customer service and getting access to my old account that had been set up with my previous application. Then I applied again with their new {$120.00} offer and the application wouldn't let me upload my Driver 's Licence. I eventually got this to work, but was declined because the info on my driver 's Licence didn't match. I got this figured out with customer service that my old profile had the wrong info. I finally got my application submitted the deadline of the {$120.00} promotion, but my account said it was setting up and I was unable to transfer money in to meet the qualifications of the bonus. The customer service rep I talked to said not to worry and to get the money transferred in as soon as I could. Fast forward to XX/XX/XXXX, and customer service refused to give me the {$120.00} bonus because I did not meet the deadline, although the previous said it was ok. I asked if I could possibly get the referral bonus that I had applied through so long ago, and they said that deadline for that had passed as well, and I'd get nothing.",
#    'date_sent_to_company': '2020-09-07T12:00:00-05:00',
#    'issue': 'Managing an account',
#    'sub_product': 'Checking account',
#    'zip_code': '98604',
#    'tags': None,
#    'complaint_id': '3833248',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2020-09-07T12:00:00-05:00',
#    'state': 'WA',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Banking errors'},
#   'sort': [32267]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '4125377',
#   '_score': None,
#   '_source': {'product': 'Checking or savings account',
#    'complaint_what_happened': "Hello, I would like to appeal this denial. I did NOT authorize these 2 ATM withdrawals. \n\n- {$160.00} - {$160.00} After landing in XXXX I did use this card once for an ATM withdrawal of {$350.00} - I received the cash and walked away. Unlike American ATM 's which makes you take your card and then output the cash ( what I am used to ) this ATM keeps your card and allows multiple withdrawals without requiring to re-enter your pin again afterwards. \n\nSecondly I did NOT authorize these 2 purchases. \n\nXXXX XXXX XXXX Debit Card - {$230.00} XXXX XXXX XXXX Debit Card - {$240.00} After realizing I left my card within 5 mins, these two big purchases were made on my card. And from the looks of it hundreds of miles away. I froze the card immediately and I called right away and was told I had to allow the transactions to process and now am being denied my funds back. Both of these charges are abnormal and out of character for me and to reiterate, I did not authorize them. \n\nThis seems very unfair that SoFi does not help their customers in any way in this matter and just sends an automated response with no information as to why my hard earned money is stolen and nothing being done about it. \n\nPlease let me know what actions I can take to move forward on retrieving this funds back. \n\nThank you!",
#    'date_sent_to_company': '2021-02-08T12:00:00-05:00',
#    'issue': 'Managing an account',
#    'sub_product': 'Checking account',
#    'zip_code': '11206',
#    'tags': None,
#    'complaint_id': '4125377',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2021-02-08T12:00:00-05:00',
#    'state': 'NY',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Problem using a debit or ATM card'},
#   'sort': [32899]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '2832873',
#   '_score': None,
#   '_source': {'product': 'Student loan',
#    'complaint_what_happened': 'I signed up through https : //www.sofi.comXXXX to refinance XXXX {$30000.00} in student loans with a promotional offer of XXXX XXXX point for every {$2.00} refinanced. I even called in after to confirm that I was enrolled. Upon having the loan funded, as expected I reached the screen where I entered my XXXX account information. \n\nThinking I was all set, I waited about a month for the points to get deposited in my account before contacting SoFi. I got a canned response " We can not apply a new link after it has been 30 days since your original loan funded. The system locks out the manual adjustment option after the 30 day time period. \'\' Attempts to escalate this internally got nowhere. \n\nI would not have chosen SoFi if it did not have this offer.',
#    'date_sent_to_company': '2018-03-05T12:00:00-05:00',
#    'issue': 'Getting a loan',
#    'sub_product': 'Private student loan',
#    'zip_code': 'XXXXX',
#    'tags': None,
#    'complaint_id': '2832873',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with non-monetary relief',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2018-03-05T12:00:00-05:00',
#    'state': 'NY',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Confusing or misleading advertising'},
#   'sort': [34341]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '2704148',
#   '_score': None,
#   '_source': {'product': 'Credit reporting, credit repair services, or other personal consumer reports',
#    'complaint_what_happened': '',
#    'date_sent_to_company': '2017-10-17T12:00:00-05:00',
#    'issue': 'Improper use of your report',
#    'sub_product': 'Credit reporting',
#    'zip_code': '87106',
#    'tags': None,
#    'complaint_id': '2704148',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent not provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2017-10-17T12:00:00-05:00',
#    'state': 'NM',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': "Credit inquiries on your report that you don't recognize"},
#   'sort': [35669]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '3729454',
#   '_score': None,
#   '_source': {'product': 'Checking or savings account',
#    'complaint_what_happened': "Executive Summary : SoFi unilaterially cancelled my debit card, after changing from Visa to Mastercard. After promising to provide a replacement, SoFi has failed, after four months and six requests via telephone, to provide a replacement card. \n\nEarly in XXXX, SoFi informed me that it was changing from Visa to  Mastercard for SoFi debit cards, would be cancelling my SoFi Visa debit card, and sending me a SoFi Mastercard debit card to replace it. From memory, the Visa debit card was cancelled at the end of XXXX, XXXX. When SoFi cancelled the Visa card, I had not received the Mastercard replacement. As of today, XX/XX/XXXX, I have made six phone calls to SoFi customer service inquiring about the replacement. The next-to-last call, on XX/XX/XXXX, the representative informed me that although I had updated my address ( I moved from XXXX XXXX to XXXX XXXX at the end of XX/XX/XXXX, at which time I change changed my address using the SoFi app ), SoFi was still sending cards to my former address in XXXX   XXXX. After a phone call today, I have spent 3.1 hours addressing the situation. For a sixth time today, a telephone representative of SoFi promised to send my a new debit card to my XXXX address. As I have no confidence in SoFi 's competence to complete this task, I am escalating my complaint to the CFPB. In addition to demanding my card, I demand compensation of {$620.00} for the time I have spent addressing the issue. ( {$200.00} x 3.1 hours )",
#    'date_sent_to_company': '2020-07-04T12:00:00-05:00',
#    'issue': 'Managing an account',
#    'sub_product': 'Checking account',
#    'zip_code': '75206',
# ...
#    'date_received': '2019-03-26T12:00:00-05:00',
#    'state': None,
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Deposits and withdrawals'},
#   'sort': [874534]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '4276973',
#   '_score': None,
#   '_source': {'product': 'Checking or savings account',
#    'complaint_what_happened': "On Tuesday XX/XX/2021, {$8900.00} USD was withdrawn from my bank account from SoFi, I do not have a SoFi account or know anyone that have one. Additionally, I received {$100.00} USD from XXXX. I did my own research and the {$100.00} was their sign-up promotional. I did not authorize the sign-up for XXXX. I have contacted my bank, and now I would like to file a complaint about SoFi and XXXX. I never authorized any of it, I don't even know the XXXX  account that was supposedly made under my information.",
#    'date_sent_to_company': '2021-04-07T12:00:00-05:00',
#    'issue': 'Problem with a lender or other company charging your account',
#    'sub_product': 'Checking account',
#    'zip_code': '62864',
#    'tags': None,
#    'complaint_id': '4276973',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2021-04-07T12:00:00-05:00',
#    'state': 'IL',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Transaction was not authorized'},
#   'sort': [874682]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '4184615',
#   '_score': None,
#   '_source': {'product': 'Mortgage',
#    'complaint_what_happened': '',
#    'date_sent_to_company': '2021-03-04T12:00:00-05:00',
#    'issue': 'Trouble during payment process',
#    'sub_product': 'Conventional home mortgage',
#    'zip_code': '75209',
#    'tags': None,
#    'complaint_id': '4184615',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent not provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2021-03-04T12:00:00-05:00',
#    'state': 'TX',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': None},
#   'sort': [874939]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '2901301',
#   '_score': None,
#   '_source': {'product': 'Student loan',
#    'complaint_what_happened': '',
#    'date_sent_to_company': '2018-05-09T12:00:00-05:00',
#    'issue': 'Dealing with your lender or servicer',
#    'sub_product': 'Federal student loan servicing',
#    'zip_code': None,
#    'tags': None,
#    'complaint_id': '2901301',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'N/A',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Phone',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2018-05-09T12:00:00-05:00',
#    'state': None,
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Received bad information about your loan'},
#   'sort': [875574]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '5687419',
#   '_score': None,
#   '_source': {'product': 'Credit card or prepaid card',
#    'complaint_what_happened': '',
#    'date_sent_to_company': '2022-06-20T12:00:00-05:00',
#    'issue': 'Problem with a purchase shown on your statement',
#    'sub_product': 'General-purpose credit card or charge card',
#    'zip_code': '11229',
#    'tags': None,
#    'complaint_id': '5687419',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent not provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2022-06-20T12:00:00-05:00',
#    'state': 'NY',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Card was charged for something you did not purchase with the card'},
#   'sort': [875779]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '4644450',
#   '_score': None,
#   '_source': {'product': 'Credit card or prepaid card',
#    'complaint_what_happened': "I filed dispute case with sofi credit card {$9.00}. I was told the case would be resolved in 3 days on XX/XX/XXXX. I reviewed a mail from SoFi dispute department named XXXX, she told me dispute denied due to no rights of recovery. Unfortunately, we have no recourse in this matter. Her phone number is XXXX. Extension XXXX. I left her voice message, she never call me back. Customer service couldn't do anything.",
#    'date_sent_to_company': '2021-09-08T12:00:00-05:00',
#    'issue': 'Problem with a purchase shown on your statement',
#    'sub_product': 'General-purpose credit card or charge card',
#    'zip_code': '19143',
#    'tags': None,
#    'complaint_id': '4644450',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2021-08-19T12:00:00-05:00',
#    'state': 'PA',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': "Credit card company isn't resolving a dispute about a purchase on your statement"},
#   'sort': [876555]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '3054744',
#   '_score': None,
#   '_source': {'product': 'Debt collection',
#    'complaint_what_happened': '',
#    'date_sent_to_company': '2018-10-24T12:00:00-05:00',
#    'issue': 'Attempts to collect debt not owed',
#    'sub_product': 'I do not know',
#    'zip_code': '60653',
#    'tags': None,
#    'complaint_id': '3054744',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent not provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2018-10-24T12:00:00-05:00',
#    'state': 'IL',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Debt is not yours'},
#   'sort': [876654]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '3601556',
#   '_score': None,
#   '_source': {'product': 'Student loan',
#    'complaint_what_happened': '',
#    'date_sent_to_company': '2020-04-10T12:00:00-05:00',
#    'issue': 'Getting a loan',
#    'sub_product': 'Private student loan',
#    'zip_code': '02115',
#    'tags': None,
#    'complaint_id': '3601556',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent not provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2020-04-10T12:00:00-05:00',
#    'state': 'MA',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Fraudulent loan'},
#   'sort': [878018]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '5677312',
#   '_score': None,
#   '_source': {'product': 'Checking or savings account',
#    'complaint_what_happened': '',
#    'date_sent_to_company': '2022-06-16T12:00:00-05:00',
#    'issue': 'Problem with a lender or other company charging your account',
#    'sub_product': 'Checking account',
#    'zip_code': '49091',
#    'tags': None,
#    'complaint_id': '5677312',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent not provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2022-06-16T12:00:00-05:00',
#    'state': 'MI',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Transaction was not authorized'},
#   'sort': [878071]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '5626094',
#   '_score': None,
#   '_source': {'product': 'Checking or savings account',
#    'complaint_what_happened': '',
#    'date_sent_to_company': '2022-06-02T12:00:00-05:00',
#    'issue': 'Opening an account',
#    'sub_product': 'Checking account',
#    'zip_code': '10040',
#    'tags': None,
#    'complaint_id': '5626094',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent not provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2022-06-02T12:00:00-05:00',
#    'state': 'NY',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': "Didn't receive terms that were advertised"},
#   'sort': [878131]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '4550268',
#   '_score': None,
#   '_source': {'product': 'Checking or savings account',
#    'complaint_what_happened': "From XXXX XXXX Sofi froze my account because someone DEPOSITED money in their name in my account. They said it is Fraud when it comes from my Employer who wants me to do payroll. But it is Legal to DEPOSIT MONEY IN someone else 's name into your account. I have been constantly sending emails and voicemails to them. They have refused to ANSWER ME. After the phone call from the so CALLED security member. They have my tax money as well. Which I worked for last year. The money is mine and they lied saying that they were sending the money to me and closing the Account. I have Investments going on and they won't let me do anything.",
#    'date_sent_to_company': '2021-08-09T12:00:00-05:00',
#    'issue': 'Managing an account',
#    'sub_product': 'Checking account',
#    'zip_code': '639XX',
#    'tags': None,
#    'complaint_id': '4550268',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2021-07-16T12:00:00-05:00',
#    'state': 'MO',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Deposits and withdrawals'},
#   'sort': [878552]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '5323438',
#   '_score': None,
#   '_source': {'product': 'Payday loan, title loan, or personal loan',
#    'complaint_what_happened': '',
#    'date_sent_to_company': '2022-03-15T12:00:00-05:00',
#    'issue': 'Struggling to pay your loan',
#    'sub_product': 'Installment loan',
#    'zip_code': '11203',
#    'tags': None,
#    'complaint_id': '5323438',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent not provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2022-03-15T12:00:00-05:00',
#    'state': 'NY',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': None},
#   'sort': [879092]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '3000608',
#   '_score': None,
#   '_source': {'product': 'Debt collection',
#    'complaint_what_happened': '',
#    'date_sent_to_company': '2018-08-24T12:00:00-05:00',
#    'issue': 'Took or threatened to take negative or legal action',
#    'sub_product': 'I do not know',
#    'zip_code': '90650',
#    'tags': None,
#    'complaint_id': '3000608',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent not provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2018-08-24T12:00:00-05:00',
#    'state': 'CA',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Sued you without properly notifying you of lawsuit'},
#   'sort': [879936]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '3772711',
#   '_score': None,
#   '_source': {'product': 'Checking or savings account',
#    'complaint_what_happened': '',
#    'date_sent_to_company': '2020-07-30T12:00:00-05:00',
#    'issue': 'Managing an account',
#    'sub_product': 'Checking account',
#    'zip_code': '23322',
#    'tags': 'Servicemember',
#    'complaint_id': '3772711',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent not provided',
#    'company_response': 'Closed with monetary relief',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2020-07-30T12:00:00-05:00',
#    'state': 'VA',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Banking errors'},
#   'sort': [880073]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '5588078',
#   '_score': None,
#   '_source': {'product': 'Checking or savings account',
#    'complaint_what_happened': '',
#    'date_sent_to_company': '2022-05-22T12:00:00-05:00',
#    'issue': 'Managing an account',
#    'sub_product': 'Checking account',
#    'zip_code': '31211',
#    'tags': 'Servicemember',
#    'complaint_id': '5588078',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent not provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2022-05-22T12:00:00-05:00',
#    'state': 'GA',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Deposits and withdrawals'},
#   'sort': [880193]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '4074118',
#   '_score': None,
#   '_source': {'product': 'Checking or savings account',
#    'complaint_what_happened': '',
#    'date_sent_to_company': '2021-01-17T12:00:00-05:00',
#    'issue': 'Opening an account',
#    'sub_product': 'Checking account',
#    'zip_code': '92056',
#    'tags': None,
#    'complaint_id': '4074118',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent not provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2021-01-17T12:00:00-05:00',
#    'state': 'CA',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': "Didn't receive terms that were advertised"},
#   'sort': [880729]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '5247200',
#   '_score': None,
#   '_source': {'product': 'Checking or savings account',
#    'complaint_what_happened': '',
#    'date_sent_to_company': '2022-02-22T12:00:00-05:00',
#    'issue': 'Managing an account',
#    'sub_product': 'Checking account',
#    'zip_code': '77479',
#    'tags': None,
#    'complaint_id': '5247200',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'N/A',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Referral',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2022-02-19T12:00:00-05:00',
#    'state': 'TX',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': 'Deposits and withdrawals'},
#   'sort': [880801]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '3280533',
#   '_score': None,
#   '_source': {'product': 'Money transfer, virtual currency, or money service',
#    'complaint_what_happened': '',
#    'date_sent_to_company': '2019-06-21T12:00:00-05:00',
#    'issue': 'Problem with customer service',
#    'sub_product': 'Debt settlement',
#    'zip_code': None,
#    'tags': None,
#    'complaint_id': '3280533',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'N/A',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Phone',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2019-06-19T12:00:00-05:00',
#    'state': None,
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': None},
#   'sort': [881422]},
#  {'_index': 'complaint-public-v2',
#   '_type': '_doc',
#   '_id': '5762530',
#   '_score': None,
#   '_source': {'product': 'Payday loan, title loan, or personal loan',
#    'complaint_what_happened': '',
#    'date_sent_to_company': '2022-07-12T12:00:00-05:00',
#    'issue': 'Getting a line of credit',
#    'sub_product': 'Personal line of credit',
#    'zip_code': '30341',
#    'tags': None,
#    'complaint_id': '5762530',
#    'timely': 'Yes',
#    'consumer_consent_provided': 'Consent not provided',
#    'company_response': 'Closed with explanation',
#    'submitted_via': 'Web',
#    'company': 'Social Finance, Inc.',
#    'date_received': '2022-07-12T12:00:00-05:00',
#    'state': 'GA',
#    'consumer_disputed': 'N/A',
#    'company_public_response': None,
#    'sub_issue': None},
#   'sort': [881607]}]

# %%
type(data)
# Out:
# list

# %%
len(data)
# Out:
# 992

# %%
# target first dictionary: source>issue, complaint_what_happened, company_response, product, consumer_disputed
test_list = data[1]
test_list
# type(test_list)
# Out:
# {'_index': 'complaint-public-v2',
#  '_type': '_doc',
#  '_id': '3162894',
#  '_score': None,
#  '_source': {'product': 'Checking or savings account',
#   'complaint_what_happened': "I was promised a {$200.00} bonus for opening my 'SoFi Money ' account. I joined a waiting list and later was sent an email telling me my account was opened successfully. SoFi falsely advertised this promotion and conducted a bait-and-switch scheme, baited new customer and deny the promotion without notice.",
#   'date_sent_to_company': '2019-02-26T12:00:00-05:00',
#   'issue': 'Managing an account',
#   'sub_product': 'Other banking product or service',
#   'zip_code': '94536',
#   'tags': None,
#   'complaint_id': '3162894',
#   'timely': 'Yes',
#   'consumer_consent_provided': 'Consent provided',
#   'company_response': 'Closed with explanation',
#   'submitted_via': 'Web',
#   'company': 'Social Finance, Inc.',
#   'date_received': '2019-02-26T12:00:00-05:00',
#   'state': 'CA',
#   'consumer_disputed': 'N/A',
#   'company_public_response': None,
#   'sub_issue': 'Banking errors'},
#  'sort': [4730]}

# %%
# test_list is a dictionary. This confirms that our data is a list of dictionaries
# let's get all the things we need
test_list.get("_source").get("complaint_what_happened")

# test_list.get("_source").get("company_response")
# Out:
# "I was promised a {$200.00} bonus for opening my 'SoFi Money ' account. I joined a waiting list and later was sent an email telling me my account was opened successfully. SoFi falsely advertised this promotion and conducted a bait-and-switch scheme, baited new customer and deny the promotion without notice."

# %%
# write a forloop to extract information relating to search terms

search_terms = ["issue", "complaint_what_happened", "company_response", "product", "consumer_disputed"]
extracted_values = []

for term in search_terms:
    if term in test_list['_source']:
        extracted_values.append(test_list['_source'][term])

print(extracted_values)
# Out:
# ['Managing an account', "I was promised a {$200.00} bonus for opening my 'SoFi Money ' account. I joined a waiting list and later was sent an email telling me my account was opened successfully. SoFi falsely advertised this promotion and conducted a bait-and-switch scheme, baited new customer and deny the promotion without notice.", 'Closed with explanation', 'Checking or savings account', 'N/A']

# %%
# let's try to build code to scrape the rest of the pages

search_terms = ["issue", "complaint_what_happened", "company_response", "product", "consumer_disputed"]
extracted_values = []

for entry in data:
    if '_source' in entry and all(term in entry['_source'] for term in search_terms):
        extracted_values.append([entry['_source'][term] for term in search_terms])
    else:
        extracted_values.append([None] * len(search_terms))  

extracted_values
# Out:
# [['Problem with additional add-on products or services',
#   '',
#   'Closed with monetary relief',
#   'Payday loan, title loan, or personal loan',
#   'N/A'],
#  ['Managing an account',
#   "I was promised a {$200.00} bonus for opening my 'SoFi Money ' account. I joined a waiting list and later was sent an email telling me my account was opened successfully. SoFi falsely advertised this promotion and conducted a bait-and-switch scheme, baited new customer and deny the promotion without notice.",
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Getting the loan',
#   'On Monday, XX/XX/2021, I was looking for a {$70000.00} Personal Loan to fund a renovation I am running in my house and I checked the rates with SoFi ( Social Finance , Inc. ) and they were attractive. They only pulled a soft credit with a credit bureau ; they pre approved me. \n\nThen, next step was to send an official application, when they would pulled my credit info from a bureau. In a given screen about immigration status they offered 3 options to be chosen from : XXXX, XXXX XXXX holder, Non-immigrant ( option that would limit the the loan to T {$35000.00} XXXX. I, then, on the same day XX/XX/XXXX, chatted with a customer support representative BEFORE SUBMITTING THE APPLICATION to understand what I should do as my situation is having an EAD/Advance Parole holder with a EB-5 Green Card application approved ( I-140 ) awaiting the card to be issued. I was informed by the agent that if I had the approval letter I could submit my application, as a green card holder. \nNote : I was logged in so they have that conversation store in their system. \n\nI proceed with the application and was approved for up to {$90000.00}. I ended up keeping a {$70000.00} request. Following, they requested me to send me my docs and after a lot of back and forth a agent calledXX/XX/XXXX. stated clearly that I had to submit an I-797 Form with my green card approval to be finally approved. I sent that and after more back and forth the agent XXXX XXXX denied the loan unless I fulfilled this absurd request to add a XXXX or XXXX XX/XX/XXXX holder to my application as a co-signer ( even to get less than {$35000.00}, the opposite of what they stated before ). \n\nI refused to do so as I earned a great credit as an individual, paying my bills and taxes diligently and I am the only responsible for my personal finances. Then, they denied my request, left me without the loan and with a credit score hurt by their hard inquiry - even though I presented all documents requested.',
#   'Closed with explanation',
#   'Payday loan, title loan, or personal loan',
#   'N/A'],
#  ['Attempts to collect debt not owed',
#   '',
#   'Closed with explanation',
#   'Debt collection',
#   'N/A'],
#  ['Dealing with your lender or servicer',
#   'On XX/XX/XXXX of XXXX, I consolidated 6 private loans under three different loan servicers : XXXX ( 1 loanXXXX XXXX XXXX {$7200.00} ), XXXX ( 3 loans- XXXX XXXX XXXX- {$1300.00}, XXXX- {$2700.00}, and Perkins loan- {$3000.00} ) , and XXXX ( 2 loans-XXXX XXXX- {$6500.00} and XXXX- {$8600.00} ) with Sofi for XXXX. XXXX then became my consolidated loan servicer. In XXXX of XXXX, I noticed that I kept receiving XXXX bank statements to re-pay my loan. I also noticed that my beginning balance at XXXX ( {$30000.00} ) dropped to {$20000.00} within 3 months. I called Sofi 4 times in regards to this situation. The final representantive I spoke with ( a member of their specialist team ), stated that Sofi made an error and did not include my XXXX loan. A previous representative I spoke with told me that Sofi would " take care of the issue since this was an error on Sofi \'s end. \'\' I was never notified by Sofi about the exclusion of the XXXX loan and thus, was late on my XXXX payments as I was under the impression that Sofi had consolidated all 6 loans. Sofi is now stating that I must re-start the loan application process and now consolidate XXXX with XXXX in order to resolve the situation for their error.',
#   'Closed with explanation',
#   'Student loan',
#   'N/A'],
#  ['Closing an account',
#   'I previously opened an installment loan with Sofi ; that was paid off. Sofi then proceeded to add an investment and checking account to my profile.I did not ask for these accounts. As a result, my tax filings are much more complicated. My accountant is charging me a higher amount of money to complete filings. \n\nI need Sofi to close these accounts and reimburse me for the extra costs I have incurred for accounts I did NOT authorize to be opened. \n\nCLOSE my accounts. I am DONE with my business with you and I was DONE when I paid off my loan!',
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Incorrect information on your report',
#   'SoFi lending is reporting an account on my credit report that I do not owe. In 2017, SoFi sued me claiming I owed this debt, but I do not and the case was dismissed. Despite this, SoFi continues to unlawfully pursue collection of this debt.\n\nI have repeatedly disputed this account with all three credit bureaus and I have written to SoFi directly to dispute the debt. However, SoFi continues to verify the debt with the credit bureaus and provide inaccurate account information.\n\nI am requesting that SoFi immediately remove this account from my credit report with all three bureaus, including, but not limited to XXXX, XXXX, and XXXX. I am further requesting that SoFi discontinue all unlawful collection activity.',
#   'Closed with explanation',
#   'Credit reporting, credit repair services, or other personal consumer reports',
#   'N/A'],
#  ["Problem with a credit reporting company's investigation into an existing problem",
#   '',
#   'Closed with explanation',
#   'Credit reporting, credit repair services, or other personal consumer reports',
#   'N/A'],
#  ['Dealing with your lender or servicer',
#   'on XX/XX/2021. I applied for student debt consolidation from XXXX to Sofi. I was under the impression that I had XXXX days ( XX/XX/2021 ) to agree to the loan. Upon hearing that there may be talks to cancel student debt and refinance with XXXX instead, i asked Sofi to cancel my refinance. They told me " no \'\' that the deadline was XX/XX/2021. The loan documents that I received from Sofi repeatedly stated XX/XX/XXXX. When I contacted Sofi they told me i can ask XXXX to return the check and cancel the refinance. When I contacted XXXX, they told me they cant do anything. I feel like I was misled, any loan that I have applied for gives XXXX days for final approval. No one from Sofi reached out to me regarding the XXXX day deadline, while all the paperwork stated XX/XX/2021. I do not know how many other students are being misled. I would like my loan returned to XXXX XXXX XXXX XXXX XXXX XXXX  and cancel any consolidation with SoFi. Anyone reading this, keep your student loans with the XXXX XXXX XXXX and do not get misled by the private loan companies.',
#   'Closed with explanation',
#   'Student loan',
#   'N/A'],
#  ['Getting a loan',
#   "I applied as a cosigner in XX/XX/2019 with SOFI to refinance my daughters student loans. I completed the credit application and provided all documentation requested. I was never notified of a credit decision. My daughter was sent an email on XX/XX/XXXX that I was ineligible as a cosigner. I contacted SOFI on XX/XX/XXXX, and was told over the phone that my credit application was WITHDRAWN and an email was sent to me on XX/XX/XXXX, I did not know what WITHDRAWN meant considering i applied for credit and provided all necessary documentation for a credit review and was told that a hard credit pull was completed. I asked to speak to a manager to file a formal complaint based on the fact that I applied for credit regardless I was a cosigner or primary that I completed a credit application and provided any requested supporting documents which included a hard credit pull that I was not formally notified of a decision simply that they could just withdraw my request for credit. My complaint I believe includes several of illegal business practices. I believe if I did not qualify under SOFI 's standards then the application should have been declined, I should have received a formal notification in writing which would allow me to follow up as a consumer. I do not understand how a company can legally pull my credit and then simply Withdraw my application and not provide information to the consumer. I do not understand how the other party involved my daughter the primary applicant received an email that I as the cosigner was ineligible, when I myself as the applicant did not receive proper notice. I believe legally when a consumer applies for credit via a credit application provides all necessary documentation to complete the application the application needs to either be declined or approved and the consumer needs to be formally notified. I do not see how SOFI can legally pull a hard credit pull find a reason not to qualify my request and simply WITHDRAW my application. Tell me that my application is Withdrawn, and email my daughter that I am ineligible and not give me any information on why I failed to meet or what their credit requirements entail.",
#   'Closed with explanation',
#   'Student loan',
#   'N/A'],
#  ['Opening an account',
#   'On XX/XX/XXXX, I referred a friend for a SoFi banking account based on a promotion where we both would receive {$15.00} and I would receive {$25.00}. \n\nMy friend completed all requires steps of creating a login, opening, and funding the account. However, a referral bonus did not post.\n\nAfter discussing with an agent, I was told that Sofi decided to end the promotion early and that they were not currently paying out bonuses. I informed the rep that I met the terms before the promotion ended and they were unsure if the promotion would be paid. I was told a complaint would be filed on my behalf but never heard back. Today on XX/XX/XXXX, I reached out to Sofi again and they told me there were no longer any referral records or tickets logged on my account. They appear to have never investigated this issue.',
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ["Problem with a credit reporting company's investigation into an existing problem",
#   '',
#   'Closed with explanation',
#   'Credit reporting, credit repair services, or other personal consumer reports',
#   'N/A'],
#  ['Managing an account',
#   "In XX/XX/2021, I filed disputes for transactions in my account that I didn't authorize that happened on my debit card as well as a check that was written on my account and for filing the dispute the closed my account never refunded my transactions and now I can't even access my bank statements I had with them. I had the XXXX XXXX XXXX that was supposed to be deposited into this account and they rejected it as well.",
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Problem with a purchase shown on your statement',
#   '',
#   'Closed with explanation',
#   'Credit card or prepaid card',
#   'N/A'],
#  ['Took or threatened to take negative or legal action',
#   'I have contact this company about this debt that was inserted into my credit profile I have contact the company asking this company to contact my attorney about this debt this account refuse and is still threatening me and now is currently in litigation. This company threaten for my credit to be rued and this company is single handily worked on destroying my credit and I am asking for help before I processed with legal actions. Thanks',
#   'Closed with explanation',
#   'Debt collection',
#   'N/A'],
#  ['Managing an account',
#   "Hello there, I'm writing in because I have, seemingly, no other alternative. The company in question is SOFI Financial. I had a checking and savings account with them that has been opened for years. Recently, I also applied for, and was approved for a credit card with them. I activated said card and was declined. I thought that was odd, so I tried once more, and was declined. I received no call from them at all regarding this- which I also found odd. \n\nI call and they tell me that my entire account, checking/savings/credit card, has been frozen for suspected fraud. Mind you, my checking account has no transactions whatsoever on them. My credit card was brand new. I had planned to utilize both once I received the card. \n\nMy actually issue lies in the fact that reaching someone at SOFI who can give me actual information as to why my account was frozen, or any details at all about my account is near impossible. Reaching a general agent is fine, until you get through and they direct you to reach their fraud team who I can never get through to whatsoever. Immediately when I am transferred, or call the number directly, I am sent to a voicemail box in which I have left 4 voicemails on already on the following dates : XX/XX/XXXX, XX/XX/XXXX, XX/XX/XXXX, XX/XX/XXXX. \n\nI have received no response or correspondence back. I have also asked for their general support team to have a supervisor call me back and have received nothing back in return either. \n\nAll accounts are frozen without any reason, ways to resolve the freeze, or ways in which to reach someone who can provide me any information at all.",
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Getting a loan',
#   'Every month I receive from XXXX an invitation to lower the cost of my student debt : " We \'ve missed you! \'\' Simply log in and check your rates. I apply and always get rejected. they keep sending me an invitation to re-apply " XXXXXXXX is the 5th one of these I \'ve received. The latest one onXX/XX/XXXX, 2017.',
#   'Closed with explanation',
#   'Student loan',
#   'N/A'],
#  ['Getting the loan',
#   "In early XX/XX/2018, I applied on www.SoFi.com for a personal loan. I have excellent credit and income and met all of the qualifications necessary to receive the loan amount of $ XXXX that I applied for. I went through the SoFi account review process submitting all required bank account documentation and proof of income and was approved for a loan. When the review process was completed I was sent my loan agreement and signed it on XX/XX/2018. My first payment on the loan was to be due on XX/XX/2018. However, for some reason, SoFi has refused to fund my loan and hasn't given me any plausible explanation. It is now XX/XX/2018 and SoFi has not funded the loan per our agreement. Every time I have contacted the company about the status of my loan they have only offered vague excuses and empty promises of the funding being ready to go. My SoFi account has now been placed in permanent 'signature review ' status. SoFi recently notified me that my application has expired even after I have provided everything that they've asked for. Based on my experience with this company I strongly suspect that I have been discriminated against based on race or because I am a senior citizen.",
#   'Closed with explanation',
#   'Payday loan, title loan, or personal loan',
#   'N/A'],
#  ['Getting the loan',
#   'SoFi heavily solicited me with a " pre-approved \'\' offer of a loan for {$50000.00}. I finally accepted their pre-approval and submitted the requested documentation to prove identity and income. Shortly after discovering I was XXXX XXXX through means of my driver \'s license the company denied my loan citing an inability to verify my income. I have worked for the same company for well over a year, the company did not ask me to provide additional documents or even give me a chance to " verify \'\' my income. When I called to have a more detailed description of the reason for denial the representative thought the denial reason was " odd \'\' and said so directly. I personally know of other well qualified high earning XXXX XXXX that received pre-approvals and were then " denied \'\' mysteriously from this company after their identity was verified. It is my strong belief that this company discriminates against XXXX XXXX. When I asked for how they determined my income could not be " verified \'\' they refused to release the name of any agency or consumer reporting agency that they based their decision off of. They wrongly justified their position of not releasing the agency used to make their decision as proprietary information, despite the fair credit reporting act specifying otherwise. There unethical lending practices lured me into applying for a loan product with them, leading to a hard inquiry on my credit which has prevented me from securing the loan I need with a more reputable lender.',
#   'Closed with explanation',
#   'Payday loan, title loan, or personal loan',
#   'N/A'],
#  ['Dealing with your lender or servicer',
#   'SoFi failed to let me know why they denied my loan refinance request.',
#   'Closed with explanation',
#   'Student loan',
#   'N/A'],
#  ['Opening an account',
#   'On XX/XX/2020, I opened a " Money \'\' account with SoFi. The " Cash Back Terms \'\' for this account said, " For each eligible transaction made within 60 days of the date your new SoFi Money Account is opened, SoFi will credit your account for an amount equal to 5 % of each eligible purchase, up to a maximum of {$100.00} during the Promotion Period. \'\' By XX/XX/2020 ( well within the 60-day limit ), I had made more than {$2000.00} of eligible purchases, meaning that I should receive {$100.00} cash back. SoFi has never credited my account with any cash back ( see account history ). \n\nOn XX/XX/2020, XX/XX/2020, and XX/XX/2020, I chatted with SoFi to try to resolve this issue ( see various transcripts ). On XX/XX/2020, I was told that I met all the requirements for the {$100.00} cash back, and each time I was told that SoFi was working on the problem and that it would be resolved in 10 business days ( after XX/XX/2020 ) or 3-5 business days ( after XX/XX/2020 ). But even after all of these communications, SoFi has still not credited my account with the {$100.00} cash back. \n\nI am uploading the terms of the account ( XXXX Sign Up Earn 5 % Cash Back SoFi XXXX ) ; chat transcripts from XX/XX/2020, XX/XX/2020, and XX/XX/2020 ; an email showing that a ticket was created on XX/XX/2020 ; and an account history showing all transactions on the account to date ( XXXX Account History SoFi - XXXX ).',
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Improper use of your report',
#   'I have tried contacting company in regards to an unauthorized inquiry dated XX/XX/21, however I can not get ahold of anyone in credit dept. I did not apply for an account with SoFi.',
#   'Closed with explanation',
#   'Credit reporting, credit repair services, or other personal consumer reports',
#   'N/A'],
#  ['Struggling to repay your loan',
#   "When my student loan payment was set up, I had a different employer, and my monthly payment was set, based on how much money I made with that employer. Now, I no longer work at that company, and I make significantly less money, because I'm working for myself, starting a new business. My loan payment is so high, it is more than I pay for my mortgage, and I'm struggling to make my monthly payments. I physically don't have the money to pay such a high amount every month. I've contacted my student loan company, Sofi, several times ( most recently on XX/XX/18 ) to explain that I need to lower my monthly payment to an amount that reflects my new income, but they tell me there's nothing I can do. My account is now delinquent as a result. To make matters worse, they raise my interest rate every month, making this physically impossible to ever day off in my lifetime. I've already paid back the amount I borrowed and then some, ( over the last 13 years ) but still owe the same amount I started with. I'm just looking to simply lower my monthly payment to a reasonable amount that I can keep up with. Please help.",
#   'Closed with explanation',
#   'Student loan',
#   'N/A'],
#  ['Closing an account',
#   'I have a money management checking account at SoFi bank that currently has a balance of {$1100.00}. Since XX/XX/XXXX, I have been unable to access the funds in this account as a temporary restriction has been placed on my account. \n\nIn reaching out to SoFi on XX/XX/XXXX, I was told that I would need to speak with the XXXX XXXX XXXX. Calling the phone number given to reach the XXXX XXXX XXXX provides me with a message stating : that there is no one available to take my call. But to please leave a message with my name, phone number and reference number so that a member of the team may follow up with me. Naturally, I followed these directions ; however, no follow up call or communication of any kind followed the voice message left on XX/XX/XXXX. \n\nOn XX/XX/XXXX, I left a voicemail with the XXXX XXXX XXXX stating the I would like to close my account as I did not have access to the funds within my account nor was I being provided assistance in gaining access to these funds. This voice message went unansweredas did did numerous messages over the next few months left with SoFi requesting that my account be closed and my funds returned to me. The most recent message was left XX/XX/XXXX. This message has not been answered. \n\nIt is extremely frustrating to have my messages ignored by SoFi..especially since I have followed their directions in terms of proper communication with them. It is also frustrating and puzzling that I can not access the funds in my account and that SoFi is actively preventing me from closing my account. Any help that can be provided in closing my SoFi account and having my funds immediately returned to me would be greatly appreciated.',
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Managing an account',
#   'I have not received my debit card although it has been more than the 7-10 business days allotted since the opening of my bank account with SoFi. I also received a message that my bank accounts ( BOTH CHECKING AND SAVINGS ) was frozen on XX/XX/XXXX and have been calling several phone numbers linked to SoFi. Anytime I am able to speak to an actual human, which is rare, they work for other parts of the company and state they have no ability to inform me as to why my account is frozen. They can only see that it is frozen. They always end up directing me to their Fraud Monitoring Team who has a voicemail machine acting as their liaison. Whenever I am transferred, or call their fraud team directly, their is an automated message saying that it is going to get a representative on the line for me immediately followed by, Im sorry all of our agents are busy right now, please leave a message. I have left multiple voicemails, everyday since as well as emails.',
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Managing an account',
#   "I originally tried to open a Sofi Money account in XXXX using my sister 's referral. The application would not process because I had started an application over a year ago with a different email and that email had to be used. I spent several weeks figuring this out with customer service and getting access to my old account that had been set up with my previous application. Then I applied again with their new {$120.00} offer and the application wouldn't let me upload my Driver 's Licence. I eventually got this to work, but was declined because the info on my driver 's Licence didn't match. I got this figured out with customer service that my old profile had the wrong info. I finally got my application submitted the deadline of the {$120.00} promotion, but my account said it was setting up and I was unable to transfer money in to meet the qualifications of the bonus. The customer service rep I talked to said not to worry and to get the money transferred in as soon as I could. Fast forward to XX/XX/XXXX, and customer service refused to give me the {$120.00} bonus because I did not meet the deadline, although the previous said it was ok. I asked if I could possibly get the referral bonus that I had applied through so long ago, and they said that deadline for that had passed as well, and I'd get nothing.",
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Managing an account',
#   "Hello, I would like to appeal this denial. I did NOT authorize these 2 ATM withdrawals. \n\n- {$160.00} - {$160.00} After landing in XXXX I did use this card once for an ATM withdrawal of {$350.00} - I received the cash and walked away. Unlike American ATM 's which makes you take your card and then output the cash ( what I am used to ) this ATM keeps your card and allows multiple withdrawals without requiring to re-enter your pin again afterwards. \n\nSecondly I did NOT authorize these 2 purchases. \n\nXXXX XXXX XXXX Debit Card - {$230.00} XXXX XXXX XXXX Debit Card - {$240.00} After realizing I left my card within 5 mins, these two big purchases were made on my card. And from the looks of it hundreds of miles away. I froze the card immediately and I called right away and was told I had to allow the transactions to process and now am being denied my funds back. Both of these charges are abnormal and out of character for me and to reiterate, I did not authorize them. \n\nThis seems very unfair that SoFi does not help their customers in any way in this matter and just sends an automated response with no information as to why my hard earned money is stolen and nothing being done about it. \n\nPlease let me know what actions I can take to move forward on retrieving this funds back. \n\nThank you!",
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Getting a loan',
#   'I signed up through https : //www.sofi.comXXXX to refinance XXXX {$30000.00} in student loans with a promotional offer of XXXX XXXX point for every {$2.00} refinanced. I even called in after to confirm that I was enrolled. Upon having the loan funded, as expected I reached the screen where I entered my XXXX account information. \n\nThinking I was all set, I waited about a month for the points to get deposited in my account before contacting SoFi. I got a canned response " We can not apply a new link after it has been 30 days since your original loan funded. The system locks out the manual adjustment option after the 30 day time period. \'\' Attempts to escalate this internally got nowhere. \n\nI would not have chosen SoFi if it did not have this offer.',
#   'Closed with non-monetary relief',
#   'Student loan',
#   'N/A'],
#  ['Improper use of your report',
#   '',
#   'Closed with explanation',
#   'Credit reporting, credit repair services, or other personal consumer reports',
#   'N/A'],
#  ['Managing an account',
#   "Executive Summary : SoFi unilaterially cancelled my debit card, after changing from Visa to Mastercard. After promising to provide a replacement, SoFi has failed, after four months and six requests via telephone, to provide a replacement card. \n\nEarly in XXXX, SoFi informed me that it was changing from Visa to  Mastercard for SoFi debit cards, would be cancelling my SoFi Visa debit card, and sending me a SoFi Mastercard debit card to replace it. From memory, the Visa debit card was cancelled at the end of XXXX, XXXX. When SoFi cancelled the Visa card, I had not received the Mastercard replacement. As of today, XX/XX/XXXX, I have made six phone calls to SoFi customer service inquiring about the replacement. The next-to-last call, on XX/XX/XXXX, the representative informed me that although I had updated my address ( I moved from XXXX XXXX to XXXX XXXX at the end of XX/XX/XXXX, at which time I change changed my address using the SoFi app ), SoFi was still sending cards to my former address in XXXX   XXXX. After a phone call today, I have spent 3.1 hours addressing the situation. For a sixth time today, a telephone representative of SoFi promised to send my a new debit card to my XXXX address. As I have no confidence in SoFi 's competence to complete this task, I am escalating my complaint to the CFPB. In addition to demanding my card, I demand compensation of {$620.00} for the time I have spent addressing the issue. ( {$200.00} x 3.1 hours )",
#   'Closed with monetary relief',
#   'Checking or savings account',
#   'N/A'],
#  ['Credit monitoring or identity theft protection services',
#   '',
#   'Closed with explanation',
#   'Credit reporting, credit repair services, or other personal consumer reports',
#   'N/A'],
#  ['Applying for a mortgage or refinancing an existing mortgage',
#   '',
#   'Closed with explanation',
#   'Mortgage',
#   'N/A'],
#  ['Problem with a purchase shown on your statement',
#   "Late XXXX XXXX I applied and was approved with a SoFi Credit Card . \n\nXX/XX/XXXX, XXXX USPS informed me via their USPS Informed Delivery that a SoFi correspondence is coming and shall be received within the day. It never came. \n\nThe week of XXXX XXXX I have filed for an unclaimed letter at USPS but they never got back to me. \n\nThe week of XXXX XXXX I called SoFi customer service people regarding my concern of not receiving the card. They advised me to wait and call back within a week before they can replace the card. \n\nXXXX XXXX I received an email and text that they have noticed a transaction at XXXX XXXX XXXX , NY for {$940.00}. I called them and told them that I have not received the card and have not activated the card. They said that I am not liable for it and it will be investigated. \n\nThe following week, XXXX XXXX- SoFi 's investigator told me to secure a Statement/ affidavit of loss from the customer service in order for me to file a police report. She told me that after filing a police report, I should give her the incident number, Name of the Police, Address and Fax number. I called the SoFi 's customer service and asked for the said document but sent me a current balance which is {$0.00} as of XX/XX/2021. I have been calling them regarding the said Affidavit of Fraud Form but still they are unaware of the said document. \n\nXXXX XXXX I was surprised that they have completed their own investigation and that they have concluded that I was liable for the said transaction. They have not even presented any proof that I made the said transaction. XXXX XXXX even told me that I have the card, I made the said transaction which is absurd, First of all, How can I file a complaint without SoFi giving me the said affidavit? I was in the police station to file a complaint but they can not entertain me without the said affidavit of fraud from the credit card company. \n\nI have been calling SoFi but we are just running circles. How did they came up such conclusion that I made such fraudulent transaction? Did they even check the IP address that was used if was used via online transaction at XXXX XXXX XXXX?, the phone number that was used to activate the card? did they even check and coordinated with XXXX ' CCTV if I was in the said store if it was done in person? This is just so absurd and I hope I was treated fairly in this matter. They have lapses in judgement making their fraud department unreliable.",
#   'Closed with explanation',
#   'Credit card or prepaid card',
#   'N/A'],
#  ['Closing an account',
#   'I have been unable to close my SoFi XXXX, Active Investing & Crypto Investing accounts because my Crypto Currency account has a {$.00} balance which is below the minimumSoFirequires initiate a trade. I entered an order to " Sell All \'\' my Crypto Currency balance on XX/XX/XXXX butSoFicompleted the transaction leaving my account with a {$.00} balance. I have requested thatSoFiclose my account on four separate occasions but they have not closed my account because of the miniscule balance. My most recent request to close the account was on XX/XX/XXXX. On a prior attempt to close my accountSoFireplied ; We are not able to close the XXXX account due to the small balance. Since this is below the minimum needed to sell ( {$10.00} ), we have to work on a solution. Sorry for the inconvenience.',
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Trouble during payment process',
#   "Loan Servicer : Sofi Lending Issue : Servicer is refusing to release required funds from escrow to cover mandatory homeowners insurance premium. Lender has been provided all insurance information and information has been verified with the lender. They have stated they will hold funds because their system doesn't reflect a payment due although all invoices and documents have been provided by myself and the company. Receipt of documents have been verified by the lender. The lender has excessive escrow balances and should be making payment as required but due to some sort of issue within the organization, they have not. I have attempted to rectify from XX/XX/2020 to present XX/XX/2020 including emails and phone calls.",
#   'Closed with explanation',
#   'Mortgage',
#   'N/A'],
#  ['Getting a credit card',
#   '',
#   'Closed with explanation',
#   'Credit card or prepaid card',
#   'N/A'],
#  ['Dealing with your lender or servicer',
#   'I refinanced my student loans through SoFi. I submitted an application and accepted interest rate of 3.05 % before their stated deadline of XX/XX/2021. On XX/XX/2021, I received a call from a SoFi representative stating that my interest rate was increasing to 3.55 % because they were unable to verify my income based upon my pay stub. As instructed, I uploaded my pay stub to my online portal. \n\nOn XX/XX/2021, I called SoFi to follow-up on the status. I was informed that the initial 3.05 % rate had expired. I then asked to speak with someone on their escalations team because I did not understand how the rate expired if I followed their instructions and it was SoFi \'s delay in contacting me to ask for more proof of income. I then spoke with XXXX XXXX on their escalations team to explain the situation and to explain the pay stub and prove that I made the income that I represented. It appears that SoFi was simply looking at my gross income, however, as a travel nurse, I receive tax-free funds that are no included in that gross figure they were going off of. I explained XXXX XXXX that SoFi needs to add up the gross amount as well as the tax-free portion of the pay stub. XXXX XXXX seemingly understood and said that if all of my paperwork was initially in prior to the deadline, then I should receive the 3.05 % rate. She then stated that she would have a " reviewer \'\' look at my file and get back to me ASAP. Immediately thereafter, I also uploaded a new pay stub that I received ( since I was just paid again ) as well as a copy of my bank statement to show how much income I was receiving. \n\nOn XX/XX/2021, I received an email from an " XXXX \'\' at SoFi indicating that they can only offer me a 3.55 % interest rate. I emailed XXXX XXXX asking why this was and I received a response from " XXXX XXXX \'\' indicating that the previous rate already expired and that this new rate was based on the income paperwork. This is just going in endless circles even though I accepted a rate of 3.05 % and submitted my necessary proof of income. SoFi appears to be luring consumers in with lower interest rates and then hitting them with a higher rate without any logical explanation- they simply repeat themselves over and over again. \n\nTheir delay in processing your application and general incompetence has now forced me to accept a higher interest rate.',
#   'Closed with explanation',
#   'Student loan',
#   'N/A'],
#  ['Dealing with your lender or servicer',
#   "I used a referral link to apply for a Sofi Student Loan Refinance XXXX # XXXX XXXX which was first approved on XX/XX/2020. When I applied, my referral bonus XXXX {$300.00} ) was present on the application the entire time. Sofi went through two iterations to beat my competitor 's offers and I eventually decided to go with Sofi. I had my loan funded on XX/XX/2020. Having learned from past experiences of companies refusing to pay incentive bonuses, I reached out to Sofi customer service on XX/XX/XXXX about my cashback bonus. I was contacted on XX/XX/XXXX and told the steps I needed to complete to get my bonus sent to my bank account. Over the past month I have been dealing with Sofi Customer Service trying to get them to give me my bonus. I provided the email thread of me discussing the bonus with them directly and the link I used. Of course, yesterday XXXX XX/XX/2020 ) they informed me that they were not responsible for the bonus despite it being applied to my application. Promoting cashback bonuses to have someone accept a loan and failing to provide the bonus is illegal.",
#   'Closed with explanation',
#   'Student loan',
#   'N/A'],
#  ['Dealing with your lender or servicer',
#   '',
#   'Closed with explanation',
#   'Student loan',
#   'N/A'],
#  ['Closing an account',
#   'On XX/XX/2021 I requested an ACAT to transfer all of my publicly traded stocks, and cash from the brokerage Social Finance , Inc. DBA SoFi Invest to the brokerage XXXX XXXX XXXXn the amount of {$1900.00}. \nOn XX/XX/2021 I received an email from SoFi Invest ( investsupport@sofi.com ) denying my request to transfer all of my stocks and cash out of SoFi with the following explanation : " Our Invest accounts must be funded for 60 days before an ACAT transfer out can be processed. \'\' On XX/XX/2021 I called Social Finance, Inc. at XXXX and spoke to a representative who explained to me that SoFi had denied my transfer in order to hold my stocks and cash for 60 days. I informed the representative that according to the SEC website that by law the ONLY reasons SoFi would be legally able to reject my ACAT transfer would be due to improper filing, or questions on share ownership. Neither of which apply to me. Therefore, I require SoFi to approve my ACAT and release my publicly traded stocks, and all cash ( less the {$75.00} transfer fee ) to the brokerage XXXX XXXX as requested. I alerted the representative that were the ACAT denial not reversed that I would be filing a complaint with you, the Consumer Financial Protection Bureau. \n\nI am filing this complaint in order to alert Social Finance , Inc. that they are willfully and knowingly breaking SEC regulations by denying my ACAT transfer out.',
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Getting a credit card',
#   'Sofi sent me a credit card I did not apply for. I tried to contact the company but they have no fraud department. There customer service number said they can help if its about a charge, but not on a card? \nTried to dispute with credit bureau but the said we showed you applied for it and its yours, however they will suspend the card. I have a credit card and a hard inquiry on my perfect credit and I am buying a new house and this effected my Percentage amount on my loan. \nI volunteered to do a police report or affidavit and they said it wont matter, its staying on your credit?',
#   'Closed with explanation',
#   'Credit card or prepaid card',
#   'N/A'],
#  ['Managing an account',
#   '',
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Trouble during payment process',
#   "We refinanced our primary residence mortgage with SoFi. We signed the closing documents on XXXX, on XXXX SoFi failed to payoff the amount due to our previous lender. After much communication with SoFi and the escrow agent XXXX XXXX, SoFi made the payoff to our previous lender on XXXX. SoFi apparently did not close on the loan until XXXX. We have still not recieved our excess escrow funds or an executed copy of our closing documents. On approximately XXXX, we received our first periodic mortgage statement from SoFi dated XXXX with the total amount due and a payment due date of XXXX. Our closing documents included a first payment notice that had an estimated amount due on XXXX. Since the due date of the periodic statement did not match the due date on the estimated first payment we logged into the SoFi system which reflected a due date of XXXX. On XXXX we received an automated call from SoFi stating that we are delinquent on our mortgage payment. I immediately contacted SoFi and explained the only periodic mortgage stated a initial due date of XXXX. On XXXX @ XXXX, XXXX ( # XXXX ) said this was SoFi 's mistake and I would receive a call from SoFi by end of business on XXXX to correct this. I received no call. I called again and on XXXX @ XXXX, XXXX ( # XXXX ) estimated resolution by XXXX, and at my request transferred me to a supervisor. On XXXX @ XXXX, XXXX XXXX ( # XXXX ) told me the loan overview on SoFi 's online system would be update to show the first payment was due XXXX by no later than XXXX and I would receive a call from SoFi by end of business on XXXX confirming the correction. I received no call. On XXXX & XXXX, I checked SoFi 's website and confirmed SoFi did not change in the first payment due date. On XXXX at XXXX, I spoke with XXXX ( # XXXX ) who reviewed the file and tried to reach XXXX XXXX . Without notice, I was transfered to an unnamed voicemail (XXXX ). I left a voicemail at XXXX detailing the issue. After leaving the voicemail, the system hung up on me. I called back the customer service line at XXXX, after waiting 38 minutes, I was transfered to an unnamed voicemail ( XXXX ), but was informed that the voicemail was full and the system hung up on me. On XXXX @ XXXX, I requested assistance through the SoFi website chat feature. I was chatting with XXXX XXXX, but the system disconnected me when I tried to attach a copy of the periodic statement indicating first payment due XXXX, I then chatted with XXXX and XXXX, neither of whom resolved the issue. On XXXX @ XXXX, I requested assistance through the SoFi website chat feature. I chatted with XXXX XXXX XXXX. He advised me that his supervisor said my first payment was due XXXX and SoFi intended to alter the periodic mortgage statement online to now reflect a due date of XXXX and if I paid today then there would be no fee. On XXXX @ XXXX, I paid the full amount alleged to be due on XXXX to ensure I was not delinquent on my loan and subject to a fee. This appears to be a bait and switch by SoFi to subject new mortgagees to fees by providing notice of a date due then changing the date due to an earlier date without notifying the consumer so they miss a payment and are subject to fines. Additionally, SoFi appears to work with an escrow company to improperly withhold excess escrow funds and not timely payoff existing mortgages.",
#   'Closed with explanation',
#   'Mortgage',
#   'N/A'],
#  ['Getting a line of credit',
#   "I applied for a loan XX/XX/XXXX and was denied XX/XX/XXXX due to my immigration status and with complete disregard to my credit earthiness and ability to meet Sofi 's other criteria for loan approval. \nXX/XX/XXXX - I called ( recorded the call ) and was told I should not even think of reapplying because I would not be considered for a loan if my immigrations status was the same. \nXX/XX/XXXX - I mailed a certified letter to Sofi regarding being discriminated against and have not heard back. \nDenying an individual the right to contract for a loan simply because they are not us citizens or residents is discriminatory under federal law and violates the civil rights act of 1866.",
#   'Closed with explanation',
#   'Payday loan, title loan, or personal loan',
#   'N/A'],
#  ['Taking out the loan or lease',
#   '',
#   'Closed with explanation',
#   'Consumer Loan',
#   'Yes'],
#  ['Struggling to repay your loan',
#   '',
#   'Closed with explanation',
#   'Student loan',
#   'N/A'],
#  ['Opening an account',
#   "I have an approved credit card from SoFi. I was trying to open a money account but couldn't open it. It kept telling me that a code has been sent to my phone which I would need to confirm in the app in order to proceed. I never received the code in my phone. I called SoFi and the representative said she is replacing code via text confirmation with code via email. But that didn't work either and it kept telling me a code has been sent to my phone which I never received. The operator said she would escalate this to their engineering team. XXXX hours later I received an email from SoFi stating that the issue has been closed and or resolved. I still can not open the money account because it still keeps telling me that a code has been sent to my phone which I would need to confirm in order to proceed.",
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Dealing with your lender or servicer',
#   '',
#   'Closed with explanation',
#   'Student loan',
#   'N/A'],
#  ['Getting the loan',
#   'On XX/XX/XXXX, I went to XXXX to get pre-qualified for a loan. I pre-qualified for an offer from Sofi. I then proceeded through the application on Sofi with the same information and was initially denied. I tried again with the exact same information and got a quote that was 200 basis points higher than the XXXX  offer. I reached out to Sofi and was told to proceed with my application and that they would attach the XXXX  offer to it. Therefore, I proceeded with the application and had my credit pulled. After that, I was told that Sofi would not actually price match the XXXX  offer. Again, I provided XXXX and Sofi the exact same information. Sofi told me that they might be able to reduce the rate, and came back with a 0.125 % reduction. Despite the fact that XXXX was a pre-qualified offer and I provided the same information to Sofi, my rate ended up being higher and I was misled into submitting my application by being told the XXXX offer would be attached. Sofi also emailed me back using the wrong name, which was concerning, but I assume an accidental oversight on their part.',
#   'Closed with explanation',
#   'Payday loan, title loan, or personal loan',
#   'N/A'],
#  ['Managing an account',
#   "My card and account was used WITHOUT my permission, for over a month time. I disputed all the transactions and it got denied. Whoever stole my debit card used over a XXXX dollars that I'm now out of because they didn't find a issue with the transactions. I'm very very very XXXX off.",
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Attempts to collect debt not owed',
#   'I refinanced my loan with Sofi through XXXX XXXX XXXX XXXX. Sofi cashed a check for {$27000.00} for payment of my loan in full on XX/XX/XXXX and has yet to apply the payment to my account. XXXX XXXX has an electronic copy of this check with the Sofi stamp on it, so it was most certainly cashed by Sofi on XX/XX/XXXX. Now I have two loans with payments due for the same {$27000.00} because Sofi has not updated my account to reflect the {$27000.00} payment. My account is officially past due today, although Sofi has received {$27000.00} for the balance. XXXX XXXX XXXX XXXX states they sent the following check : Check # XXXX Amount : {$27000.00} USPS Tracking Number : 940XXXX XXXX XXXX XXXX XXXX XXXX To : XXXX XXXX XXXX in XXXX Texas Again, the check was cashed by Sofi eight days ago. XXXX XXXX XXXX XXXX sent the check and then provided this information after I filed complaint # XXXX on XX/XX/2019.',
#   'Closed with explanation',
#   'Debt collection',
#   'N/A'],
#  ['Incorrect information on your report',
# ...
#   'Closed with explanation',
#   'Student loan',
#   'N/A'],
#  ['Managing an account',
#   '',
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Problem when making payments',
#   '',
#   'Closed with explanation',
#   'Payday loan, title loan, or personal loan',
#   'N/A'],
#  ['Getting a line of credit',
#   'On XX/XX/XXXX, I received a targeted advertisement in the social media platform XXXX for a personal loan to payoff credit card debt from XXXX XXXX ( SoFI ). I began the process of " checking my rates \'\' on XX/XX/XXXX, however due to the amount of information needed I did not complete the process that day. On XX/XX/XXXX and XX/XX/XXXX, I received additional emails from SoFI encouraging me to complete my application. On XX/XX/XXXX, I completed the application by providing my address, date of birth, place of employment, years of professional service, and annual salary. \nAfter requesting my rate, instead of showing the available rates ( which is what I was attempting to access ) I was notified that I had been declined for a personal loan. At no point was I advised that I was actually applying for the loan as the site left the impression I was checking the rates. \nWhen attempting to access the Adverse Action letter, I was directed to call as the reason was " other \'\'. When I called SoFI I was informed that the denial was due to my credit score was too low and my debt utilization is too high. I asked for the minimum credit score, but was advised that the required score is proprietary. I also explained that there is no adverse action letter on my account and that I expected the denial to be put in writing. The customer service agent explained that I can view in my account and seemed unconcerned when I said that it was not available online. She offered to send it to me via email, but the email I received from her only directs me back to the original link inside of the SoFI account.',
#   'Closed with explanation',
#   'Payday loan, title loan, or personal loan',
#   'N/A'],
#  ['Problem with additional add-on products or services',
#   '',
#   'Closed with explanation',
#   'Payday loan, title loan, or personal loan',
#   'N/A'],
#  ['Incorrect information on your report',
#   '',
#   'Closed with explanation',
#   'Credit reporting, credit repair services, or other personal consumer reports',
#   'N/A'],
#  ['Advertising and marketing, including promotional offers',
#   "Advertising for card said unlimited 2 % cash back. After signing up and receiving the card noticed the fine print. Saying it's actually 2 points for every dollar and depending on how you redeem it could be worth 2 %. If pure cash, it's only 1 %.",
#   'Closed with explanation',
#   'Credit card or prepaid card',
#   'N/A'],
#  ['Problem with a purchase shown on your statement',
#   '',
#   'Closed with monetary relief',
#   'Credit card or prepaid card',
#   'N/A'],
#  ['Managing an account',
#   '',
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ["Problem with a credit reporting company's investigation into an existing problem",
#   '',
#   'Closed with explanation',
#   'Credit reporting, credit repair services, or other personal consumer reports',
#   'N/A'],
#  ['Struggling to repay your loan',
#   'I started at University of XXXX in XX/XX/XXXX for a XXXX  in XXXX XXXX and successfully put my loan into deferment for three months ( the maximum amount allowed ). Around the time that the three months were up, I submitted another deferment request, because I was still in school. \nOn XX/XX/XXXX the deferment request was denied because it was not within 30 days of the end date of the original deferment. I received the notification on XX/XX/XXXX. \nI then submitted another request 1 day before the 30 days started because I figured processing with my school would take at least a day. It was denied on XX/XX/XXXX because there were missing dates of enrollment, however, the national student clearinghouse sent the correct forms with the application. I received this notification XX/XX/XXXX. \nI submitted another deferment request again after the 30 days began and it was denied on XX/XX/XXXX because it was not within the 30 days of the end date of the other deferment. I had submitted it after the 30 days but since it was signed and dated for the day before the 30 days, they denied the request. I received this notice on XX/XX/XXXX. \nI then submitted the deferment request for the FOURTH TIME. It was denied on XX/XX/XXXX again due to it not providing a program of study. I received this notification on XX/XX/XXXX. By this point it was so close to XXXX so I was unable to get anything done with my school since everyone was gone on break so I had to wait until after office personnel came back at University of XXXX. By this time it was XX/XX/XXXX. \nAt this point, I was in direct contact with one person from the registrars office and she sent the deferment request 4-5 times to Sofi/XXXX by fax and by e-mail. The only record that Sofi/XXXX  has of this is XX/XX/XXXX which they took no action and XX/XX/XXXX which they also took no action. I finally got frustrated and asked the registrar lady to just send me the forms directly so I could up load them onto my account homepage. This was against their protocol but she agreed because, I assume, she understood how much trouble this had been for me. \nI submitted the deferment request again for the FIFTH TIME on XX/XX/XXXX through the Sofi/XXXX  website and I made sure to contact Sofi/XXXX  when I submitted it to make sure everything was filled out correctly. They assured me that it would and that I would not be penalized for this since my account has been past due since I have been waiting for this deferment to go through. \nOn XX/XX/XXXX they contacted me because my account was past due and that was when they informed me that the dates were not filled out correctly AGAIN. I was forced to pay a month of my loan which I really cant afford right now and now I have to submit this deferment request again. Also, apparently I was given the incorrect information by the previous two Sofi/XXXX personnel who told me that if my deferment request was approved it would retroactively be applied through the month of XXXX. That was not true, thus the reason I had to pay for a month of student loans that I truly can not afford. \nI am submitting this complaint because Sofi/XXXX have failed to acknowledge my in-school deferment requests. They have created such a burden on me and my school by denying my requests over and over again knowing full well that I am currently in school. I have been prompt with every one of my filings and deferment requests but because of their incompetence, my account is now 37 days past due. I have done everything in my power to get them to accept my deferment requests, but they have utterly failed to perform even the most basic of tasks.',
#   'Closed with explanation',
#   'Student loan',
#   'N/A'],
#  ['Taking out the loan or lease',
#   '',
#   'Closed with explanation',
#   'Consumer Loan',
#   'Yes'],
#  ['Getting a loan',
#   "SoFi advertised new lower student loan refinancing rates after going public, and encouraged me to check my rate ( by offering me SoFi points to check my rate and apply ). Additionally, SoFi advertised via chat and their website that they had a rate match guarantee and would also give {$100.00} along with a rate match. My existing rate was lower than what SoFi showed me after I submitted my information. I asked via chat how to take advantage of the rate match guarantee. I was advised to email my proof of lower rate to SoFi 's customer service. I did so immediately, sending over my last student loan statement and loan approval letter from a couple months ago with my current lender. Two days later I had no response from SoFi, so I contacted customer service via chat. The representative confirmed the documentation I sent over and said all that was remaining was completing my application, which included a hard credit pull. I completed the application, and once SoFi approved it at their initial advertised rate, I returned to chat to have my current lower rate applied per the match guarantee. The new representative said that SoFi would not match existing loans, and that I needed a current rate offer from a competitor. This was different than what had been stated earlier the same day by a different representative. Based on the earlier communication, I only agreed to allow SoFi to hard pull my credit and submit my application under the understanding that SoFi would match my lower rate based on the documentation I submitted.\n\nAs of now, I have a ding on my credit and SoFi has changed their stance on what they told me re the match guarantee and promotional credit.",
#   'Closed with explanation',
#   'Student loan',
#   'N/A'],
#  ['Managing an account',
#   '',
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Problem with a lender or other company charging your account',
#   "On Tuesday XX/XX/2021, {$8900.00} USD was withdrawn from my bank account from SoFi, I do not have a SoFi account or know anyone that have one. Additionally, I received {$100.00} USD from XXXX. I did my own research and the {$100.00} was their sign-up promotional. I did not authorize the sign-up for XXXX. I have contacted my bank, and now I would like to file a complaint about SoFi and XXXX. I never authorized any of it, I don't even know the XXXX  account that was supposedly made under my information.",
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Trouble during payment process',
#   '',
#   'Closed with explanation',
#   'Mortgage',
#   'N/A'],
#  ['Dealing with your lender or servicer',
#   '',
#   'Closed with explanation',
#   'Student loan',
#   'N/A'],
#  ['Problem with a purchase shown on your statement',
#   '',
#   'Closed with explanation',
#   'Credit card or prepaid card',
#   'N/A'],
#  ['Problem with a purchase shown on your statement',
#   "I filed dispute case with sofi credit card {$9.00}. I was told the case would be resolved in 3 days on XX/XX/XXXX. I reviewed a mail from SoFi dispute department named XXXX, she told me dispute denied due to no rights of recovery. Unfortunately, we have no recourse in this matter. Her phone number is XXXX. Extension XXXX. I left her voice message, she never call me back. Customer service couldn't do anything.",
#   'Closed with explanation',
#   'Credit card or prepaid card',
#   'N/A'],
#  ['Attempts to collect debt not owed',
#   '',
#   'Closed with explanation',
#   'Debt collection',
#   'N/A'],
#  ['Getting a loan', '', 'Closed with explanation', 'Student loan', 'N/A'],
#  ['Problem with a lender or other company charging your account',
#   '',
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Opening an account',
#   '',
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Managing an account',
#   "From XXXX XXXX Sofi froze my account because someone DEPOSITED money in their name in my account. They said it is Fraud when it comes from my Employer who wants me to do payroll. But it is Legal to DEPOSIT MONEY IN someone else 's name into your account. I have been constantly sending emails and voicemails to them. They have refused to ANSWER ME. After the phone call from the so CALLED security member. They have my tax money as well. Which I worked for last year. The money is mine and they lied saying that they were sending the money to me and closing the Account. I have Investments going on and they won't let me do anything.",
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Struggling to pay your loan',
#   '',
#   'Closed with explanation',
#   'Payday loan, title loan, or personal loan',
#   'N/A'],
#  ['Took or threatened to take negative or legal action',
#   '',
#   'Closed with explanation',
#   'Debt collection',
#   'N/A'],
#  ['Managing an account',
#   '',
#   'Closed with monetary relief',
#   'Checking or savings account',
#   'N/A'],
#  ['Managing an account',
#   '',
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Opening an account',
#   '',
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Managing an account',
#   '',
#   'Closed with explanation',
#   'Checking or savings account',
#   'N/A'],
#  ['Problem with customer service',
#   '',
#   'Closed with explanation',
#   'Money transfer, virtual currency, or money service',
#   'N/A'],
#  ['Getting a line of credit',
#   '',
#   'Closed with explanation',
#   'Payday loan, title loan, or personal loan',
#   'N/A']]

# %%
# Add column names directly in the DataFrame 
df = pd.DataFrame(extracted_values, columns=["issue", "complaint_what_happened", "company_response", "product", "consumer_disputed"])
df
# Out:
#                                                  issue  \
# 0    Problem with additional add-on products or ser...
# 1                                  Managing an account
# 2                                     Getting the loan
# 3                    Attempts to collect debt not owed
# 4                 Dealing with your lender or servicer
# ..                                                 ...
# 987                                Managing an account
# 988                                 Opening an account
# 989                                Managing an account
# 990                      Problem with customer service
# 991                           Getting a line of credit
#
#                                complaint_what_happened  \
# 0
# 1    I was promised a {$200.00} bonus for opening m...
# 2    On Monday, XX/XX/2021, I was looking for a {$7...
# 3
# 4    On XX/XX/XXXX of XXXX, I consolidated 6 privat...
# ..                                                 ...
# 987
# 988
# 989
# 990
# 991
#
#                 company_response  \
# 0    Closed with monetary relief
# 1        Closed with explanation
# 2        Closed with explanation
# 3        Closed with explanation
# 4        Closed with explanation
# ..                           ...
# 987      Closed with explanation
# 988      Closed with explanation
# 989      Closed with explanation
# 990      Closed with explanation
# 991      Closed with explanation
#
#                                                product consumer_disputed
# 0            Payday loan, title loan, or personal loan               N/A
# 1                          Checking or savings account               N/A
# 2            Payday loan, title loan, or personal loan               N/A
# 3                                      Debt collection               N/A
# 4                                         Student loan               N/A
# ..                                                 ...               ...
# 987                        Checking or savings account               N/A
# 988                        Checking or savings account               N/A
# 989                        Checking or savings account               N/A
# 990  Money transfer, virtual currency, or money ser...               N/A
# 991          Payday loan, title loan, or personal loan               N/A
#
# [992 rows x 5 columns]

# %%
filtered_df = df[df['consumer_disputed'] != 'N/A']

# %%
filtered_df
# Out:
#                                   issue  \
# 44         Taking out the loan or lease
# 105        Taking out the loan or lease
# 213                      Getting a loan
# 253        Taking out the loan or lease
# 259        Taking out the loan or lease
# ..                                  ...
# 928        Shopping for a loan or lease
# 929        Shopping for a loan or lease
# 935          Managing the loan or lease
# 938  Dealing with my lender or servicer
# 971        Taking out the loan or lease
#
#                                complaint_what_happened  \
# 44
# 105  I would not recommend any type of loan with th...
# 213  SoFi is advertising that the average consumer ...
# 253
# 259
# ..                                                 ...
# 928
# 929  Sofi Lending reported that I applied for a loa...
# 935  I have a personal loan with SoFi. On XXXX XXXX...
# 938  I have applied for a loan to refinance my stud...
# 971
#
#             company_response        product consumer_disputed
# 44   Closed with explanation  Consumer Loan               Yes
# 105  Closed with explanation  Consumer Loan                No
# 213  Closed with explanation   Student loan               Yes
# 253  Closed with explanation  Consumer Loan                No
# 259  Closed with explanation  Consumer Loan               Yes
# ..                       ...            ...               ...
# 928  Closed with explanation  Consumer Loan                No
# 929  Closed with explanation  Consumer Loan                No
# 935  Closed with explanation  Consumer Loan                No
# 938  Closed with explanation   Student loan                No
# 971  Closed with explanation  Consumer Loan               Yes
#
# [85 rows x 5 columns]

# %%
dispute_yes = filtered_df[filtered_df["consumer_disputed"] == 'Yes']

# %%
len(dispute_yes)
# Out:
# 21

# %% [markdown]
# # In Conclusion
# #### We scraped the website using API, analyzed the number of complaints with disputes over company response and now have a full dataframe with these details.
